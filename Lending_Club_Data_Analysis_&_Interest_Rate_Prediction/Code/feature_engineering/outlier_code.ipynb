# %%
# !pip install featuretools

# %%
import featuretools as ft
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h3> DATA CLEANING </h3>

# %%
dataset = pd.read_csv('../Data/loan.csv',low_memory=False)

# %%
dataset.columns.values
# Out:
# array(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'pymnt_plan',
#        'url', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'dti',
#        'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths',
#        'mths_since_last_delinq', 'mths_since_last_record', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d',
#        'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'mths_since_last_major_derog', 'policy_code', 'application_type',
#        'annual_inc_joint', 'dti_joint', 'verification_status_joint',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_il_6m', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m',
#        'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi',
#        'total_cu_tl', 'inq_last_12m'], dtype=object)

# %%
dataset.isna().sum()
columns_with_most_nulls = []
columns_with_data=[]
for key,null_value in (dataset.isnull().sum()/len(dataset)*100).sort_values().iteritems():
    if null_value > 75:
        columns_with_most_nulls.append(key)
    else:
        columns_with_data.append(key)
print("No of columns with more than 50% missing data: ",columns_with_most_nulls)
print("No of columns with considerable amount of data: ",columns_with_data)
# Out:
# No of columns with more than 50% missing data:  ['mths_since_last_major_derog', 'mths_since_last_record', 'desc', 'inq_last_12m', 'inq_fi', 'open_acc_6m', 'open_il_6m', 'open_il_12m', 'open_il_24m', 'total_bal_il', 'total_cu_tl', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'mths_since_rcnt_il', 'il_util', 'annual_inc_joint', 'verification_status_joint', 'dti_joint']
# No of columns with considerable amount of data:  ['id', 'addr_state', 'dti', 'revol_bal', 'initial_list_status', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_amnt', 'policy_code', 'application_type', 'zip_code', 'purpose', 'out_prncp', 'funded_amnt', 'pymnt_plan', 'member_id', 'loan_status', 'issue_d', 'verification_status', 'loan_amnt', 'url', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'home_ownership', 'annual_inc', 'acc_now_delinq', 'delinq_2yrs', 'pub_rec', 'open_acc', 'inq_last_6mths', 'total_acc', 'earliest_cr_line', 'last_credit_pull_d', 'collections_12_mths_ex_med', 'title', 'revol_util', 'last_pymnt_d', 'emp_length', 'emp_title', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim', 'next_pymnt_d', 'mths_since_last_delinq']

# %%
dataset_columns_with_data = dataset[columns_with_data]

# %%
dataset_columns_with_data.isna().sum()
# Out:
# id                                 0
# addr_state                         0
# dti                                0
# revol_bal                          0
# initial_list_status                0
# out_prncp_inv                      0
# total_pymnt                        0
# total_pymnt_inv                    0
# total_rec_prncp                    0
# total_rec_int                      0
# total_rec_late_fee                 0
# recoveries                         0
# collection_recovery_fee            0
# last_pymnt_amnt                    0
# policy_code                        0
# application_type                   0
# zip_code                           0
# purpose                            0
# out_prncp                          0
# funded_amnt                        0
# pymnt_plan                         0
# member_id                          0
# loan_status                        0
# issue_d                            0
# verification_status                0
# loan_amnt                          0
# url                                0
# funded_amnt_inv                    0
# term                               0
# int_rate                           0
# installment                        0
# grade                              0
# sub_grade                          0
# home_ownership                     0
# annual_inc                         4
# acc_now_delinq                    29
# delinq_2yrs                       29
# pub_rec                           29
# open_acc                          29
# inq_last_6mths                    29
# total_acc                         29
# earliest_cr_line                  29
# last_credit_pull_d                53
# collections_12_mths_ex_med       145
# title                            152
# revol_util                       502
# last_pymnt_d                   17659
# emp_length                     44825
# emp_title                      51462
# tot_coll_amt                   70276
# tot_cur_bal                    70276
# total_rev_hi_lim               70276
# next_pymnt_d                  252971
# mths_since_last_delinq        454312
# dtype: int64

# %% [markdown]
# <h4>Droping unwanted features</h4>
# 1.we are droping features like "next_pymnt_d","last_pymnt_d","tot_coll_amt","tot_cur_bal" that will generate after a loan is started, so they have no effect on prediction of interest rates <br>
# 2.we are also dropping "emp_title" feature since borrowers economic strength is collectively dependent on annual income and employment length

# %%
dataset_columns_with_data.drop(columns=["last_pymnt_d","emp_title","tot_coll_amt","tot_cur_bal","next_pymnt_d"],inplace=True)

# %%
dataset_columns_with_data
# Out:
#               id addr_state    dti  revol_bal initial_list_status  \
# 0        1077501         AZ  27.65    13648.0                   f
# 1        1077430         GA   1.00     1687.0                   f
# 2        1077175         IL   8.72     2956.0                   f
# 3        1076863         CA  20.00     5598.0                   f
# 4        1075358         OR  17.94    27783.0                   f
# 5        1075269         AZ  11.20     7963.0                   f
# 6        1069639         NC  23.51    17726.0                   f
# 7        1072053         CA   5.35     8221.0                   f
# 8        1071795         CA   5.55     5210.0                   f
# 9        1071570         TX  18.08     9279.0                   f
# 10       1070078         AZ  16.12     4032.0                   f
# 11       1069908         CA  10.78    23336.0                   f
# 12       1064687         VA  10.08    10452.0                   f
# 13       1069866         IL  12.56     7323.0                   f
# 14       1069057         CA   7.06    11997.0                   f
# 15       1069759         MO  20.31     6524.0                   f
# 16       1065775         CA  18.60    24043.0                   f
# 17       1069971         CT  10.52    22836.0                   f
# 18       1062474         UT  18.44        0.0                   f
# 19       1069742         CA   9.86     7314.0                   f
# 20       1069740         TX  26.53    17813.0                   f
# 21       1039153         FL  13.22    32135.0                   f
# 22       1069710         TX  11.18    10056.0                   f
# 23       1069700         CA  16.01    17800.0                   f
# 24       1069559         CA   2.40     5963.0                   f
# 25       1069697         IL  29.44    13707.0                   f
# 26       1069800         NY  15.22     5872.0                   f
# 27       1069657         PA  13.97     4345.0                   f
# 28       1069799         FL   5.63     6110.0                   f
# 29       1047704         MN  12.19     6441.0                   f
# ...          ...        ...    ...        ...                 ...
# 887349  36691397         FL  27.24    21100.0                   f
# 887350  36500819         CA  15.72    10260.0                   f
# 887351  36743377         CO  36.93    12943.0                   f
# 887352  36231083         MD   8.47     9508.0                   w
# 887353  36371802         FL  15.77    14848.0                   w
# 887354  36250801         GA   2.84     6707.0                   f
# 887355  36331554         UT  18.11    32167.0                   f
# 887356  36460697         MT  31.95    41546.0                   w
# 887357  35773415         KY  11.28     7710.0                   w
# 887358  36440728         NC   5.27    17275.0                   w
# 887359  35591131         MN   5.52    13860.0                   f
# 887360  36361815         NY  29.60    75645.0                   w
# 887361  36201871         MA  17.09    23356.0                   f
# 887362  36381756         NM  17.62     4611.0                   f
# 887363  36231724         NV  25.65     8731.0                   f
# 887364  36231718         FL  13.22    10776.0                   w
# 887365  36381704         IN  16.80     2684.0                   w
# 887366  36241316         FL  18.58     1756.0                   f
# 887367  36301729         FL  33.66    10529.0                   w
# 887368  36250208         NC   1.00      672.0                   w
# 887369  36421485         CA  12.63     1700.0                   f
# 887370  35094480         WI  25.63     6361.0                   f
# 887371  36260758         OH  29.44     6987.0                   f
# 887372  36330911         OH  23.69    21110.0                   f
# 887373  36221446         TX  27.08    18266.0                   f
# 887374  36371250         CA  28.69    14037.0                   f
# 887375  36441262         NJ   3.90     8621.0                   f
# 887376  36271333         TN  30.90    11031.0                   w
# 887377  36490806         MA  27.19     8254.0                   w
# 887378  36271262         FL  10.83    33266.0                   f
#
#         out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 
# 887374        7055.47   3971.880000          3971.88          2944.53
# 887375       16933.26   9532.390000          9532.39          7066.74
# 887376       11155.50   3769.740000          3769.74          1844.50
# 887377       10447.31   3787.670000          3787.67          1552.69
# 887378       14110.94   7943.760000          7943.76          5889.06
#
#         total_rec_int           ...            inq_last_6mths  total_acc  \
# 0              861.07           ...                       1.0        9.0
# 1              435.17           ...                       5.0        4.0
# 2              603.65           ...                       2.0       10.0
# 3             2209.33           ...                       1.0       37.0
# 4             1009.07           ...                       0.0       38.0
# 5              631.38           ...                       3.0       12.0
# 6             3025.99           ...                       1.0       11.0
# 7              938.14           ...                       2.0        4.0
# 8              294.94           ...                       2.0       13.0
# 9              533.42           ...                       0.0        3.0
# 10            1177.52           ...                       2.0       23.0
# 11            1943.08           ...                       0.0       34.0
# 12             570.26           ...                       1.0        9.0
# 13             478.98           ...                       2.0       11.0
# 14            1393.42           ...                       2.0       29.0
# 15             270.17           ...                       1.0       23.0
# 16            2519.26           ...                       2.0       28.0
# 17             185.02           ...                       0.0       42.0
# 18            1149.50           ...                       0.0       14.0
# 19             259.96           ...                       0.0       28.0
# 20            7413.04           ...                       3.0       22.0
# 21            3330.44           ...                       0.0       38.0
# 22            1902.56           ...                       0.0       21.0
# 23            1536.31           ...                       0.0       17.0
# 24             475.25           ...                       1.0        7.0
# 25             823.48           ...                       0.0       31.0
# 26               0.00           ...                       1.0       11.0
# 27             719.11           ...                       0.0       22.0
# 28             484.79           ...                       0.0       44.0
# 29            1622.21           ...                       0.0       12.0
# ...               ...           ...                       ...        ...
# 887349        1186.09           ...                       1.0       27.0
# 887350        1297.21           ...                       0.0       24.0
# 887351         358.06           ...                       0.0       45.0
# 887352        1541.03           ...                       0.0       15.0
# 887353        1575.81           ...                       0.0       10.0
# 887354         928.33           ...                       0.0       16.0
# 887355        1877.16           ...                       0.0       28.0
# 887356        3317.00           ...                       0.0       29.0
# 887357        3101.21           ...                       0.0       18.0
# 887358        3700.44           ...                       0.0        7.0
# 887359        3605.43           ...                       0.0       26.0
# 887360        2127.29           ...                       0.0       21.0
# 887361        1072.26           ...                       0.0       25.0
# 887362         557.22           ...                       1.0       27.0
# 887363        1000.41           ...                       0.0       15.0
# 887364         296.87           ...                       0.0       21.0
# 887365         868.47           ...                       3.0       30.0
# 887366         825.46           ...                       1.0        4.0
# 887367         550.06           ...                       0.0       32.0
# 887368        1821.61           ...                       0.0       14.0
# 887369         158.02           ...                       0.0       30.0
# 887370         606.88           ...                       0.0       29.0
# 887371         990.28           ...                       1.0       20.0
# 887372        1232.81           ...                       0.0       61.0
# 887373        1584.85           ...                       0.0       18.0
# 887374        1027.35           ...                       0.0       15.0
# 887375        2465.65           ...                       1.0       23.0
# 887376        1925.24           ...                       0.0       22.0
# 887377        2234.98           ...                       2.0       20.0
# 887378        2054.70           ...                       1.0       10.0
#
#         earliest_cr_line  last_credit_pull_d  collections_12_mths_ex_med  \
# 0               Jan-1985            Jan-2016                         0.0
# 1               Apr-1999            Sep-2013                         0.0
# 20                   NaN                     NaN
# 21                   NaN                     NaN
# 22                   NaN                     NaN
# 23                   NaN                     NaN
# 24                   NaN                     NaN
# 25                   NaN                     NaN
# 26                   NaN                     NaN
# 27                   NaN                    20.0
# 28                   NaN                    18.0
# 29                   NaN                     NaN
# ...                  ...                     ...
# 887349           39700.0                    69.0
# 887350           22000.0                    17.0
# 887351           20400.0                    38.0
# 887352            9700.0                     NaN
# 887353           26100.0                     NaN
# 887354            8500.0                     NaN
# 887355          129100.0                     NaN
# 887356           65600.0                     NaN
# 887357           10200.0                    30.0
# 887358           18700.0                     NaN
# 887359           24400.0                     NaN
# 887360          118600.0                    17.0
# 887361           76300.0                     NaN
# 887362            7300.0                    24.0
# 887363           11900.0                     8.0
# 887364           41700.0                    16.0
# 887365            9900.0                    10.0
# 887366            1800.0                     NaN
# 887367           30300.0                    29.0
# 887368           20700.0                     NaN
# 887369           30100.0                     NaN
# 887370           14500.0                    69.0
# 887371           16800.0                    65.0
# 887372           30300.0                     9.0
# 887373           28100.0                     NaN
# 887374           17100.0                     NaN
# 887375           10200.0                    26.0
# 887376           18000.0                     NaN
# 887377           27000.0                    22.0
# 887378           41700.0                     NaN
#
# [887379 rows x 49 columns]

# %%
numerical_data = dataset_columns_with_data.select_dtypes(include = ['int64','float'])
categorical_data = dataset_columns_with_data.select_dtypes(include = ['object'])

# %%
categorical_features = categorical_data.columns.values
numerical_features = numerical_data.columns.values

# %%
dataset_columns_with_data[numerical_features].isna().sum()
# Out:
# id                                 0
# dti                                0
# revol_bal                          0
# out_prncp_inv                      0
# total_pymnt                        0
# total_pymnt_inv                    0
# total_rec_prncp                    0
# total_rec_int                      0
# total_rec_late_fee                 0
# recoveries                         0
# collection_recovery_fee            0
# last_pymnt_amnt                    0
# policy_code                        0
# out_prncp                          0
# funded_amnt                        0
# member_id                          0
# loan_amnt                          0
# funded_amnt_inv                    0
# int_rate                           0
# installment                        0
# annual_inc                         4
# acc_now_delinq                    29
# delinq_2yrs                       29
# pub_rec                           29
# open_acc                          29
# inq_last_6mths                    29
# total_acc                         29
# collections_12_mths_ex_med       145
# revol_util                       502
# total_rev_hi_lim               70276
# mths_since_last_delinq        454312
# dtype: int64

# %% [markdown]
# <h3>Handling Missing numerical data</h3>

# %%
#records which do not have column data like "annual_inc","acc_now_delinq","pub_rec","open_acc","inq_last_6mths","total_acc","collections_12_mths_ex_med","revol_util" are very less in number, so we will remove those records
dataset_columns_with_data.dropna(axis=0,subset=["annual_inc","acc_now_delinq","pub_rec","open_acc","inq_last_6mths","total_acc","collections_12_mths_ex_med","revol_util"],inplace=True)

# %%
dataset_columns_with_data[["total_rev_hi_lim","mths_since_last_delinq"]].describe()
# Out:
#        total_rev_hi_lim  mths_since_last_delinq
# count      8.167220e+05           432682.000000
# mean       3.207709e+04               34.073953
# std        3.749254e+04               21.883753
# min        0.000000e+00                0.000000
# 25%        1.400000e+04               15.000000
# 50%        2.370000e+04               31.000000
# 75%        3.980000e+04               50.000000
# max        9.999999e+06              188.000000

# %%
dataset_columns_with_data[numerical_features].corr()
# Out:
#                                   id       dti  revol_bal  out_prncp_inv  \
# id                          1.000000  0.067609   0.036407       0.558553
# dti                         0.067609  1.000000   0.067299       0.059174
# revol_bal                   0.036407  0.067299   1.000000       0.232198
# out_prncp_inv               0.558553  0.059174   0.232198       1.000000
# total_pymnt                -0.597574 -0.041556   0.138294      -0.287098
# total_pymnt_inv            -0.593161 -0.040416   0.137734      -0.283656
# total_rec_prncp            -0.556603 -0.052080   0.120160      -0.369736
# total_rec_int              -0.462330  0.008347   0.137446       0.112341
# total_rec_late_fee         -0.075830 -0.005647   0.002929      -0.032992
# recoveries                 -0.114402  0.001176   0.010814      -0.110897
# collection_recovery_fee    -0.072806  0.002185   0.008222      -0.076495
# last_pymnt_amnt            -0.229048 -0.029371   0.059068      -0.331213
# policy_code                      NaN       NaN        NaN            NaN
# out_prncp                   0.558589  0.059211   0.232193       0.999997
# funded_amnt                 0.065729  0.020958   0.333561       0.648768
# member_id                   0.999443  0.067651   0.036362       0.559004
# loan_amnt                   0.063481  0.020561   0.333689       0.646830
# funded_amnt_inv             0.071049  0.022024   0.331911       0.651459
# int_rate                   -0.143053  0.079950  -0.035604       0.042525
# installment                 0.025005  0.014219   0.316683       0.548045
# annual_inc                  0.033970 -0.087371   0.295535       0.211285
# acc_now_delinq              0.016873  0.003226  -0.000837       0.012351
# delinq_2yrs                 0.049649 -0.002828  -0.032436       0.031652
# pub_rec                     0.080084 -0.022981  -0.100734      -0.007759
# open_acc                    0.088483  0.144126   0.224578       0.171682
# inq_last_6mths             -0.126782 -0.008045  -0.017529      -0.106685
# total_acc                   0.031270  0.107946   0.189163       0.137854
# collections_12_mths_ex_med  0.051314 -0.000295  -0.022871       0.016065
# revol_util                 -0.055253  0.087817   0.216249       0.074432
# total_rev_hi_lim            0.048735  0.032915   0.821106       0.222650
# mths_since_last_delinq     -0.008941  0.001311  -0.026911      -0.036984
#
#                             total_pymnt  total_pymnt_inv  total_rec_prncp  \
# id                            -0.597574        -0.593161        -0.556603
# dti                           -0.041556        -0.040416        -0.052080
# revol_bal                      0.138294         0.137734         0.120160
# out_prncp_inv                 -0.287098        -0.283656        -0.369736
# total_pymnt                    1.000000         0.997648         0.970042
# total_pymnt_inv                0.997648         1.000000         0.967557
# total_rec_prncp                0.970042         0.967557         1.000000
# total_rec_int                  0.681670         0.680970         0.489336
# total_rec_late_fee             0.056297         0.053453         0.033109
# recoveries                     0.038410         0.037012        -0.037703
# collection_recovery_fee        0.036364         0.034079        -0.022904
# last_pymnt_amnt                0.658787         0.659326         0.741885
# policy_code                         NaN              NaN              NaN
# out_prncp                     -0.287107        -0.283670        -0.369741
# funded_amnt                    0.473199         0.474361         0.389162
# member_id                     -0.597091        -0.592556        -0.556312
# loan_amnt                      0.474542         0.475521         0.390396
# funded_amnt_inv                0.468830         0.473894         0.384862
# int_rate                       0.170555         0.171501         0.055005
# installment                    0.514886         0.515710         0.449384
# annual_inc                     0.160775         0.160730         0.149889
# acc_now_delinq                -0.008480        -0.008241        -0.010821
# delinq_2yrs                   -0.031825        -0.031389        -0.038312
# pub_rec                       -0.087913        -0.087157        -0.084531
# open_acc                       0.042601         0.043807         0.031151
# inq_last_6mths                 0.077795         0.074074         0.062470
# total_acc                      0.109078         0.110020         0.099947
# collections_12_mths_ex_med    -0.039016        -0.038666        -0.038149
# revol_util                     0.081857         0.083070         0.037444
# total_rev_hi_lim               0.119391         0.119400         0.118184
# mths_since_last_delinq        -0.007602        -0.005375         0.000561
#
#                             total_rec_int  total_rec_late_fee  recoveries  \
# id                              -0.462330           -0.075830   -0.114402
# dti                              0.008347           -0.005647    0.001176
# revol_bal                        0.137446            0.002929    0.010814
# out_prncp_inv                    0.112341           -0.032992   -0.110897
# total_pymnt                      0.681670            0.056297    0.038410
# total_pymnt_inv                  0.680970            0.053453    0.037012
# total_rec_prncp                  0.489336            0.033109   -0.037703
# total_rec_int                    1.000000            0.090439    0.067842
# total_rec_late_fee               0.090439            1.000000    0.073675
# recoveries                       0.067842            0.073675    1.000000
# collection_recovery_fee          0.051993            0.068558    0.802466
# last_pymnt_amnt                  0.136211           -0.013231   -0.037044
# policy_code                           NaN                 NaN         NaN
# out_prncp                        0.112328           -0.032987   -0.110897
# funded_amnt                      0.532792            0.031317    0.072694
# member_id                       -0.461417           -0.076172   -0.114489
# loan_amnt                        0.533845            0.031629    0.073156
# funded_amnt_inv                  0.530358            0.028332    0.070782
# int_rate                         0.445767            0.057131    0.106830
# installment                      0.498587            0.042046    0.074564
# annual_inc                       0.128480            0.013564    0.007700
# acc_now_delinq                   0.002212            0.003148    0.000721
# delinq_2yrs                      0.001696            0.017327   -0.000716
# pub_rec                         -0.060109           -0.011424   -0.014480
# open_acc                         0.061240           -0.009440    0.001590
# inq_last_6mths                   0.085738            0.031302    0.045586
# total_acc                        0.091896           -0.004812    0.009396
# collections_12_mths_ex_med      -0.024996           -0.003060   -0.004787
# revol_util                       0.183473            0.022192    0.028560
# total_rev_hi_lim                 0.072075           -0.005200    0.000014
# mths_since_last_delinq          -0.028363           -0.021045   -0.004543
#
#                                      ...            acc_now_delinq  \
# id                                   ...                  0.016873
# dti                                  ...                  0.003226
# revol_bal                            ...                 -0.000837
# out_prncp_inv                        ...                  0.012351
# total_pymnt                          ...                 -0.008480
# total_pymnt_inv                      ...                 -0.008241
# total_rec_prncp                      ...                 -0.010821
# total_rec_int                        ...                  0.002212
# total_rec_late_fee                   ...                  0.003148
# recoveries                           ...                  0.000721
# collection_recovery_fee              ...                  0.000387
# last_pymnt_amnt                      ...                 -0.003155
# policy_code                          ...                       NaN
# out_prncp                            ...                  0.012360
# funded_amnt                          ...                  0.003964
# member_id                            ...                  0.016980
# loan_amnt                            ...                  0.003859
# funded_amnt_inv                      ...                  0.004186
# int_rate                             ...                  0.026480
# installment                          ...                  0.006498
# annual_inc                           ...                  0.014747
# acc_now_delinq                       ...                  1.000000
# delinq_2yrs                          ...                  0.130180
# pub_rec                              ...                  0.000364
# open_acc                             ...                  0.017780
# inq_last_6mths                       ...                 -0.005367
# total_acc                            ...                  0.026482
# collections_12_mths_ex_med           ...                  0.039661
# revol_util                           ...                 -0.027658
# total_rev_hi_lim                     ...                  0.008269
# mths_since_last_delinq               ...                 -0.139138
#
#                             delinq_2yrs   pub_rec  open_acc  inq_last_6mths  \
# id                             0.049649  0.080084  0.088483       -0.126782
# dti                           -0.002828 -0.022981  0.144126       -0.008045
# revol_bal                     -0.032436 -0.100734  0.224578       -0.017529
# out_prncp_inv                  0.031652 -0.007759  0.171682       -0.106685
# total_pymnt                   -0.031825 -0.087913  0.042601        0.077795
# total_pymnt_inv               -0.031389 -0.087157  0.043807        0.074074
# total_rec_prncp               -0.038312 -0.084531  0.031151        0.062470
# total_rec_int                  0.001696 -0.060109  0.061240        0.085738
# total_rec_late_fee             0.017327 -0.011424 -0.009440        0.031302
# recoveries                    -0.000716 -0.014480  0.001590        0.045586
# collection_recovery_fee        0.000992 -0.008788  0.003260        0.034031
# last_pymnt_amnt               -0.019437 -0.034249  0.028086        0.060131
# policy_code                         NaN       NaN       NaN             NaN
# out_prncp                      0.031663 -0.007762  0.171679       -0.106665
# funded_amnt                    0.000259 -0.080960  0.199320       -0.034608
# member_id                      0.049905  0.080746  0.088596       -0.127082
# loan_amnt                     -0.000052 -0.081301  0.198830       -0.034091
# funded_amnt_inv                0.000756 -0.079933  0.199921       -0.038643
# int_rate                       0.055111  0.052226 -0.010047        0.227977
# installment                    0.007985 -0.070082  0.183830       -0.003493
# annual_inc                     0.047443 -0.008309  0.138610        0.035342
# acc_now_delinq                 0.130180  0.000364  0.017780       -0.005367
# delinq_2yrs                    1.000000 -0.010968  0.051442        0.021344
# pub_rec                       -0.010968  1.000000 -0.025522        0.056850
# open_acc                       0.051442 -0.025522  1.000000        0.111355
# inq_last_6mths                 0.021344  0.056850  0.111355        1.000000
# total_acc                      0.122729  0.012367  0.695194        0.135845
# collections_12_mths_ex_med     0.063074  0.021037  0.009577        0.006861
# revol_util                    -0.017254 -0.079703 -0.143920       -0.087883
# total_rev_hi_lim              -0.040961 -0.100237  0.325753        0.005816
# mths_since_last_delinq        -0.562949  0.096607 -0.043585        0.015040
#
#                             total_acc  collections_12_mths_ex_med  revol_util  \
# id                           0.031270                    0.051314   -0.055253
# dti                          0.107946                   -0.000295    0.087817
# revol_bal                    0.189163                   -0.022871    0.216249
# out_prncp_inv                0.137854                    0.016065    0.074432
# total_pymnt                  0.109078                   -0.039016    0.081857
# total_pymnt_inv              0.110020                   -0.038666    0.083070
# total_rec_prncp              0.099947                   -0.038149    0.037444
# total_rec_int                0.091896                   -0.024996    0.183473
# total_rec_late_fee          -0.004812                   -0.003060    0.022192
# recoveries                   0.009396                   -0.004787    0.028560
# collection_recovery_fee      0.010353                   -0.002982    0.018802
# last_pymnt_amnt              0.086188                   -0.017874   -0.001451
# policy_code                       NaN                         NaN         NaN
# out_prncp                    0.137840                    0.016080    0.074483
# funded_amnt                  0.222531                   -0.016490    0.120009
# member_id                    0.031439                    0.051425   -0.054975
# loan_amnt                    0.222592                   -0.016649    0.119517
# funded_amnt_inv              0.222727                   -0.016063    0.120698
# int_rate                    -0.038554                    0.013360    0.269090
# installment                  0.200364                   -0.014101    0.131747
# annual_inc                   0.187391                   -0.003948    0.036786
# acc_now_delinq               0.026482                    0.039661   -0.027658
# delinq_2yrs                  0.122729                    0.063074   -0.017254
# pub_rec                      0.012367                    0.021037   -0.079703
# open_acc                     0.695194                    0.009577   -0.143920
# inq_last_6mths               0.135845                    0.006861   -0.087883
# total_acc                    1.000000                    0.008830   -0.113242
# collections_12_mths_ex_med   0.008830                    1.000000   -0.036130
# revol_util                  -0.113242                   -0.036130    1.000000
# total_rev_hi_lim             0.255966                   -0.017260   -0.117444
# mths_since_last_delinq      -0.045219                   -0.035853    0.012478
#
#                             total_rev_hi_lim  mths_since_last_delinq
# id                                  0.048735               -0.008941
# dti                                 0.032915                0.001311
# revol_bal                           0.821106               -0.026911
# out_prncp_inv                       0.222650               -0.036984
# total_pymnt                         0.119391               -0.007602
# total_pymnt_inv                     0.119400               -0.005375
# total_rec_prncp                     0.118184                0.000561
# total_rec_int                       0.072075               -0.028363
# total_rec_late_fee                 -0.005200               -0.021045
# recoveries                          0.000014               -0.004543
# collection_recovery_fee             0.001603               -0.005234
# last_pymnt_amnt                     0.062182                0.007130
# policy_code                              NaN                     NaN
# out_prncp                           0.222608               -0.036999
# funded_amnt                         0.312450               -0.038542
# member_id                           0.048670               -0.009092
# loan_amnt                           0.312451               -0.038495
# funded_amnt_inv                     0.312484               -0.036352
# int_rate                           -0.166055               -0.030126
# installment                         0.286837               -0.041788
# annual_inc                          0.268802               -0.050356
# acc_now_delinq                      0.008269               -0.139138
# delinq_2yrs                        -0.040961               -0.562949
# pub_rec                            -0.100237                0.096607
# open_acc                            0.325753               -0.043585
# inq_last_6mths                      0.005816                0.015040
# total_acc                           0.255966               -0.045219
# collections_12_mths_ex_med         -0.017260               -0.035853
# revol_util                         -0.117444                0.012478
# total_rev_hi_lim                    1.000000               -0.028838
# mths_since_last_delinq             -0.028838                1.000000
#
# [31 rows x 31 columns]

# %%
f,ax = plt.subplots(figsize=(25, 25))
sns.heatmap(dataset_columns_with_data[numerical_features].corr(), annot=True, linewidths=1, fmt= '.1f',ax=ax)
plt.show()

# %% [markdown]
# <h4>Removing highly collinear features</h4>

# %%
highly_collinear_features=["total_pymnt_inv","total_rec_prncp","funded_amnt_inv","funded_amnt"]

# %%
dataset_columns_with_data.drop(columns=highly_collinear_features,inplace=True)

# %% [markdown]
# Removing non ordinal features

# %%
dataset_columns_with_data.drop(columns=["id"],inplace=True)

# %%
numerical_data = dataset_columns_with_data.select_dtypes(include = ['int64','float'])
categorical_data = dataset_columns_with_data.select_dtypes(include = ['object'])
categorical_features = categorical_data.columns.values
numerical_features = numerical_data.columns.values

# %%
print(len(numerical_features),len(categorical_features))
# Out:
# 26 18

# %%
dataset_columns_with_data.corr()['int_rate'].sort_values(ascending=False)
# Out:
# int_rate                      1.000000
# total_rec_int                 0.445767
# revol_util                    0.269090
# inq_last_6mths                0.227977
# total_pymnt                   0.170555
# loan_amnt                     0.145040
# installment                   0.133064
# recoveries                    0.106830
# last_pymnt_amnt               0.101188
# dti                           0.079950
# collection_recovery_fee       0.070885
# total_rec_late_fee            0.057131
# delinq_2yrs                   0.055111
# pub_rec                       0.052226
# out_prncp                     0.042668
# out_prncp_inv                 0.042525
# acc_now_delinq                0.026480
# collections_12_mths_ex_med    0.013360
# open_acc                     -0.010047
# mths_since_last_delinq       -0.030126
# revol_bal                    -0.035604
# total_acc                    -0.038554
# annual_inc                   -0.072848
# member_id                    -0.142296
# total_rev_hi_lim             -0.166055
# policy_code                        NaN
# Name: int_rate, dtype: float64

# %%
dataset_columns_with_data.isna().sum()
# Out:
# addr_state                         0
# dti                                0
# revol_bal                          0
# initial_list_status                0
# out_prncp_inv                      0
# total_pymnt                        0
# total_rec_int                      0
# total_rec_late_fee                 0
# recoveries                         0
# collection_recovery_fee            0
# last_pymnt_amnt                    0
# policy_code                        0
# application_type                   0
# zip_code                           0
# purpose                            0
# out_prncp                          0
# pymnt_plan                         0
# member_id                          0
# loan_status                        0
# issue_d                            0
# verification_status                0
# loan_amnt                          0
# url                                0
# term                               0
# int_rate                           0
# installment                        0
# grade                              0
# sub_grade                          0
# home_ownership                     0
# annual_inc                         0
# acc_now_delinq                     0
# delinq_2yrs                        0
# pub_rec                            0
# open_acc                           0
# inq_last_6mths                     0
# total_acc                          0
# earliest_cr_line                   0
# last_credit_pull_d                51
# collections_12_mths_ex_med         0
# title                            151
# revol_util                         0
# emp_length                     44810
# total_rev_hi_lim               70042
# mths_since_last_delinq        454082
# dtype: int64

# %%
#removing some more highly collinear features
dataset_columns_with_data.drop(columns=["total_rev_hi_lim","collection_recovery_fee","out_prncp_inv","total_acc","mths_since_last_delinq"],inplace=True)

# %%
dataset_columns_with_data.isna().sum()
# Out:
# addr_state                        0
# dti                               0
# revol_bal                         0
# initial_list_status               0
# total_pymnt                       0
# total_rec_int                     0
# total_rec_late_fee                0
# recoveries                        0
# last_pymnt_amnt                   0
# policy_code                       0
# application_type                  0
# zip_code                          0
# purpose                           0
# out_prncp                         0
# pymnt_plan                        0
# member_id                         0
# loan_status                       0
# issue_d                           0
# verification_status               0
# loan_amnt                         0
# url                               0
# term                              0
# int_rate                          0
# installment                       0
# grade                             0
# sub_grade                         0
# home_ownership                    0
# annual_inc                        0
# acc_now_delinq                    0
# delinq_2yrs                       0
# pub_rec                           0
# open_acc                          0
# inq_last_6mths                    0
# earliest_cr_line                  0
# last_credit_pull_d               51
# collections_12_mths_ex_med        0
# title                           151
# revol_util                        0
# emp_length                    44810
# dtype: int64

# %%
#removing user filled data like title for the loan since we will know the purpose
dataset_columns_with_data.drop(columns=["title"],inplace=True)

# %%
dataset_columns_with_data["emp_length"]=dataset_columns_with_data["emp_length"].fillna(0)

# %%
dataset_columns_with_data.dropna(axis=0,subset=["last_credit_pull_d"],inplace=True)

# %%
numerical_data = dataset_columns_with_data.select_dtypes(include = ['int64','float'])
categorical_data = dataset_columns_with_data.select_dtypes(include = ['object'])
categorical_features = categorical_data.columns.values
numerical_features = numerical_data.columns.values

# %%
#checking if any data is left unhandled
dataset_columns_with_data.isna().sum()
# Out:
# addr_state                    0
# dti                           0
# revol_bal                     0
# initial_list_status           0
# total_pymnt                   0
# total_rec_int                 0
# total_rec_late_fee            0
# recoveries                    0
# last_pymnt_amnt               0
# policy_code                   0
# application_type              0
# zip_code                      0
# purpose                       0
# out_prncp                     0
# pymnt_plan                    0
# member_id                     0
# loan_status                   0
# issue_d                       0
# verification_status           0
# loan_amnt                     0
# url                           0
# term                          0
# int_rate                      0
# installment                   0
# grade                         0
# sub_grade                     0
# home_ownership                0
# annual_inc                    0
# acc_now_delinq                0
# delinq_2yrs                   0
# pub_rec                       0
# open_acc                      0
# inq_last_6mths                0
# earliest_cr_line              0
# last_credit_pull_d            0
# collections_12_mths_ex_med    0
# revol_util                    0
# emp_length                    0
# dtype: int64

# %%
#generating clean data
dataset_columns_with_data.to_csv("../Data/dataclean.csv")

# %%
dataset_columns_with_data.shape
# Out:
# (886713, 38)

# %% [markdown]
# Handling categorical data

# %%
categorical_features
# Out:
# array(['addr_state', 'initial_list_status', 'application_type',
#        'zip_code', 'purpose', 'pymnt_plan', 'loan_status', 'issue_d',
#        'verification_status', 'url', 'term', 'grade', 'sub_grade',
#        'home_ownership', 'earliest_cr_line', 'last_credit_pull_d',
#        'emp_length'], dtype=object)

# %%
numerical_features
# Out:
# array(['dti', 'revol_bal', 'total_pymnt', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'last_pymnt_amnt',
#        'policy_code', 'out_prncp', 'member_id', 'loan_amnt', 'int_rate',
#        'installment', 'annual_inc', 'acc_now_delinq', 'delinq_2yrs',
#        'pub_rec', 'open_acc', 'inq_last_6mths',
#        'collections_12_mths_ex_med', 'revol_util'], dtype=object)

# %%
dataset_columns_with_data[numerical_features].corr()['int_rate'].sort_values(ascending =False)
# Out:
# int_rate                      1.000000
# total_rec_int                 0.445779
# revol_util                    0.269078
# inq_last_6mths                0.227997
# total_pymnt                   0.170574
# loan_amnt                     0.145056
# installment                   0.133079
# recoveries                    0.106831
# last_pymnt_amnt               0.101195
# dti                           0.079944
# total_rec_late_fee            0.057132
# delinq_2yrs                   0.055102
# pub_rec                       0.052217
# out_prncp                     0.042668
# acc_now_delinq                0.026480
# collections_12_mths_ex_med    0.013358
# open_acc                     -0.010048
# revol_bal                    -0.035604
# annual_inc                   -0.072845
# member_id                    -0.142316
# policy_code                        NaN
# Name: int_rate, dtype: float64

# %%
#removing installment as it is highly collinear with loan_amount
dataset_columns_with_data.drop(columns=["installment"],inplace=True)

# %%
#removing columns member id since it is non ordinal, policy_code as it does not have any correlation with interest rate
dataset_columns_with_data.drop(columns=["member_id","policy_code"],inplace=True)

# %%
numerical_data = dataset_columns_with_data.select_dtypes(include = ['int64','float'])
categorical_data = dataset_columns_with_data.select_dtypes(include = ['object'])
categorical_features = categorical_data.columns.values
numerical_features = numerical_data.columns.values

# %%
f,ax = plt.subplots(figsize=(25, 25))
sns.heatmap(dataset_columns_with_data.corr(), annot=True, linewidths=1, fmt= '.1f',ax=ax)
plt.show()

# %%
dataset_columns_with_data.corr()['int_rate'].sort_values(ascending=False)
# Out:
# int_rate                      1.000000
# total_rec_int                 0.445779
# revol_util                    0.269078
# inq_last_6mths                0.227997
# total_pymnt                   0.170574
# loan_amnt                     0.145056
# recoveries                    0.106831
# last_pymnt_amnt               0.101195
# dti                           0.079944
# total_rec_late_fee            0.057132
# delinq_2yrs                   0.055102
# pub_rec                       0.052217
# out_prncp                     0.042668
# acc_now_delinq                0.026480
# collections_12_mths_ex_med    0.013358
# open_acc                     -0.010048
# revol_bal                    -0.035604
# annual_inc                   -0.072845
# Name: int_rate, dtype: float64

# %% [markdown]
# <h3>Handling Categorical Data</h3>

# %%
f,ax = plt.subplots(figsize=(25, 25))
sns.heatmap(pd.get_dummies(dataset_columns_with_data["emp_length"],drop_first=True).corr(), annot=True, linewidths=1, fmt= '.1f',ax=ax)
plt.show()

# %%
len(numerical_features)
print(numerical_features)
# Out:
# ['dti' 'revol_bal' 'total_pymnt' 'total_rec_int' 'total_rec_late_fee'
#  'recoveries' 'last_pymnt_amnt' 'out_prncp' 'loan_amnt' 'int_rate'
#  'annual_inc' 'acc_now_delinq' 'delinq_2yrs' 'pub_rec' 'open_acc'
#  'inq_last_6mths' 'collections_12_mths_ex_med' 'revol_util']

# %%
len(categorical_features)
print(categorical_features)
# Out:
# ['addr_state' 'initial_list_status' 'application_type' 'zip_code'
#  'purpose' 'pymnt_plan' 'loan_status' 'issue_d' 'verification_status'
#  'url' 'term' 'grade' 'sub_grade' 'home_ownership' 'earliest_cr_line'
#  'last_credit_pull_d' 'emp_length']

# %% [markdown]
# <h3> Handling categorical values </h3>

# %% [markdown]
# <ul>Ordinal Values
# <li>grade</li>
# <li>emp_length</li>
# </ul>
# <ul>Nominal Values
# <li>home_ownership</li>
# <li>verification_status</li>
# <li>purpose</li>
# <li>term</li>
# <li>addr_state</li>
# </ul>

# %%
# we will remove columns :URL,pymnt_plan, loan_status, zip_code - as these columns hold less significance in intrest rate calculation
dataset_columns_with_data.drop(columns =['url','loan_status','zip_code','pymnt_plan'], inplace=True)

# %%
#we noticed that first row's values for both earliest_cr_line and last_credit_pull_d columns contain date values that would require a good amount of feature engineering for them to be potentially useful:
# earliest_cr_line — The month the borrower's earliest reported credit line was opened
# last_credit_pull_d — The most recent month Lending Club pulled credit for this loan
# We'll remove these date columns from the DataFrame.
dataset_columns_with_data.drop(columns =['issue_d','initial_list_status','earliest_cr_line','last_credit_pull_d'], inplace=True)

# %%
numerical_data = dataset_columns_with_data.select_dtypes(include = ['int64','float'])
categorical_data = dataset_columns_with_data.select_dtypes(include = ['object'])
categorical_features = categorical_data.columns.values
numerical_features = numerical_data.columns.values

# %%
print(categorical_features)
# Out:
# ['addr_state' 'application_type' 'purpose' 'verification_status' 'term'
#  'grade' 'sub_grade' 'home_ownership' 'emp_length']

# %%
sub_grades=[]
for key in dataset_columns_with_data.sub_grade.value_counts().to_dict().keys():
    sub_grades.append(key)

# %%
sorted(sub_grades)
# Out:
# ['A1',
#  'A2',
#  'A3',
#  'A4',
#  'A5',
#  'B1',
#  'B2',
#  'B3',
#  'B4',
#  'B5',
#  'C1',
#  'C2',
#  'C3',
#  'C4',
#  'C5',
#  'D1',
#  'D2',
#  'D3',
#  'D4',
#  'D5',
#  'E1',
#  'E2',
#  'E3',
#  'E4',
#  'E5',
#  'F1',
#  'F2',
#  'F3',
#  'F4',
#  'F5',
#  'G1',
#  'G2',
#  'G3',
#  'G4',
#  'G5']

# %%
ordinal_features_map = {
   "emp_length": {
       "10+ years": 10,
       "9 years": 9,
       "8 years": 8,
       "7 years": 7,
       "6 years": 6,
       "5 years": 5,
       "4 years": 4,
       "3 years": 3,
       "2 years": 2,
       "1 year": 1,
       "< 1 year": 0,
       "n/a": 0

   },
   "grade":{
       "A": 1,
       "B": 2,
       "C": 3,
       "D": 4,
       "E": 5,
       "F": 6,
       "G": 7
   },
   "sub_grade":{
       'A1':1,
       'A2':2,
       'A3':3,
       'A4':4,
       'A5':5,
       'B1':6,
       'B2':7,
       'B3':8,
       'B4':9,
       'B5':10,
       'C1':11,
       'C2':12,
       'C3':13,
       'C4':14,
       'C5':15,
       'D1':16,
       'D2':17,
       'D3':18,
       'D4':19,
       'D5':20,
       'E1':21,
       'E2':22,
       'E3':23,
       'E4':24,
       'E5':25,
       'F1':26,
       'F2':27,
       'F3':28,
       'F4':29,
       'F5':30,
       'G1':31,
       'G2':32,
       'G3':33,
       'G4':34,
       'G5':35
   }
}
dataset_columns_with_data=dataset_columns_with_data.replace(ordinal_features_map)

# %%
numerical_data = dataset_columns_with_data.select_dtypes(include = ['int64','float'])
categorical_data = dataset_columns_with_data.select_dtypes(include = ['object'])
categorical_features = categorical_data.columns.values
numerical_features = numerical_data.columns.values
categorical_features=categorical_features.tolist()

# %%
categorical_features
# Out:
# ['addr_state',
#  'application_type',
#  'purpose',
#  'verification_status',
#  'term',
#  'home_ownership']

# %%
dataset_columns_with_data_copy=dataset_columns_with_data
print(len(dataset_columns_with_data_copy.columns.values),len(dataset_columns_with_data.columns.values))
# Out:
# 27 27

# %%
def onehotencoder(dataset_columns_with_data,column):
    return dataset_columns_with_data.drop(columns=[column]).join(pd.get_dummies(dataset_columns_with_data[column],drop_first=True))
#replacing nominal categorical features with numeric data using one hot encoding technique
for feature in categorical_features:
    dataset_columns_with_data = onehotencoder(dataset_columns_with_data,feature)

# %%
dataset_columns_with_data
# Out:
#           dti  revol_bal   total_pymnt  total_rec_int  total_rec_late_fee  \
# 0       27.65    13648.0   5861.071414         861.07                0.00
# 1        1.00     1687.0   1008.710000         435.17                0.00
# 2        8.72     2956.0   3003.653644         603.65                0.00
# 3       20.00     5598.0  12226.302212        2209.33               16.97
# 887377  27.19     8254.0   3787.670000        2234.98                0.00
# 887378  10.83    33266.0   7943.760000        2054.70                0.00
#
#         recoveries  last_pymnt_amnt  out_prncp  loan_amnt  int_rate  ...   \
# 0             0.00           171.62       0.00     5000.0     10.65  ...
# 1           117.08           119.66       0.00     2500.0     15.27  ...
# 2             0.00           649.91       0.00     2400.0     15.96  ...
# 3             0.00           357.48       0.00    10000.0     13.49  ...
# 4             0.00            67.79     766.90     3000.0     12.69  ...
# 5             0.00           161.03       0.00     5000.0      7.90  ...
# 6             0.00           170.08    1889.15     7000.0     15.96  ...
# 7             0.00           111.34       0.00     3000.0     18.64  ...
# 8           189.06           152.39       0.00     5600.0     21.28  ...
# 9           269.29           121.45       0.00     5375.0     12.69  ...
# 10            0.00          1655.54       0.00     6500.0     14.65  ...
# 11            0.00          6315.30       0.00    12000.0     12.69  ...
# 12          444.30           305.38       0.00     9000.0     13.49  ...
# 13            0.00           102.43       0.00     3000.0      9.91  ...
# 14          645.10           325.74       0.00    10000.0     10.65  ...
# 15            0.00            36.32       0.00     1000.0     16.29  ...
# 16            0.00           370.46       0.00    10000.0     15.27  ...
# 17            0.00           583.45       0.00     3600.0      6.03  ...
# 18            0.00            16.98       0.00     6000.0     11.71  ...
# 19            0.00          8061.10       0.00     9200.0      6.03  ...
# 20            0.00          6024.09       0.00    20250.0     15.27  ...
# 21            0.00           701.73       0.00    21000.0     12.42  ...
# 22            0.00           349.21       0.00    10000.0     11.71  ...
# 23            0.00          4942.63       0.00    10000.0     11.71  ...
# 24          269.31           198.46       0.00     6000.0     11.71  ...
# 25            0.00          2447.05       0.00    15000.0      9.91  ...
# 26            0.00             0.00       0.00    15000.0     14.27  ...
# 27          260.96           123.65       0.00     5000.0     16.77  ...
# 28            0.00          2638.77       0.00     4000.0     11.71  ...
# 29            0.00           581.59       0.00     8500.0     11.71  ...
# ...            ...              ...        ...        ...       ...  ...
# 887349        0.00           617.46   13792.10    20000.0      6.99  ...
# 887350        0.00           237.86    8758.52    10300.0     13.66  ...
# 887351        0.00           147.64       0.00     4200.0     15.99  ...
# 887352        0.00           498.15   10583.21    15000.0     11.99  ...
# 887353        0.00           329.44   12641.60    15000.0     11.44  ...
# 887354        0.00           216.50    4342.24     6000.0     17.86  ...
# 887355        0.00           846.88   18689.12    26950.0      8.19  ...
# 887356        0.00           554.32   19705.00    23000.0     15.59  ...
# 887357        0.00           473.44   16157.04    18700.0     17.86  ...
# 887358        0.00           607.82   21451.02    25000.0     15.99  ...
# 887359        0.00           602.52   21418.50    25000.0     15.59  ...
# 887360        0.00           545.87   22073.98    26500.0      8.67  ...
# 887361        0.00           639.15   14416.53    21000.0      6.03  ...
# 887362        0.00           251.40    5547.70     8000.0      8.19  ...
# 887363        0.00           384.34    8053.46    12000.0      9.49  ...
# 887364        0.00          9439.34       0.00    10775.0      6.03  ...
# 887365        0.00           240.30    4989.63     7000.0     14.31  ...
# 887366        0.00          4858.17       0.00     6225.0     16.49  ...
# 7          0      0    0     1
# 8          0      0    1     0
# 9          0      0    0     1
# 10         0      0    1     0
# 11         0      0    1     0
# 12         0      0    0     1
# 13         0      0    0     1
# 14         0      0    0     1
# 15         0      0    0     1
# 16         0      0    0     1
# 17         0      0    0     0
# 18         0      0    0     0
# 19         0      0    0     1
# 20         0      0    0     1
# 21         0      0    0     1
# 22         0      0    1     0
# 23         0      0    0     1
# 24         0      0    0     1
# 25         0      0    0     0
# 26         0      0    0     1
# 27         0      0    0     1
# 28         0      0    0     0
# 29         0      0    0     1
# ...      ...    ...  ...   ...
# 887349     0      0    0     0
# 887350     0      0    0     1
# 887351     0      0    0     0
# 887352     0      0    0     1
# 887353     0      0    0     1
# 887354     0      0    0     0
# 887355     0      0    0     1
# 887356     0      0    0     0
# 887357     0      0    0     1
# 887358     0      0    0     1
# 887359     0      0    1     0
# 887360     0      0    0     0
# 887361     0      0    0     0
# 887362     0      0    0     0
# 887363     0      0    0     1
# 887364     0      0    0     1
# 887365     0      0    0     1
# 887366     0      0    0     1
# 887367     0      0    0     1
# 887368     0      0    0     0
# 887369     0      0    0     0
# 887370     0      0    0     1
# 887371     0      0    1     0
# 887372     0      0    0     0
# 887373     0      0    0     1
# 887374     0      0    0     1
# 887375     0      0    0     0
# 887376     0      0    0     1
# 887377     0      0    0     1
# 887378     0      0    0     1
#
# [886713 rows x 93 columns]

# %% [markdown]
# <h4>verifying that all columns are numeric are not</h4>

# %%
numerical_data = dataset_columns_with_data.select_dtypes(include = ['int64','float','uint8'])
categorical_data = dataset_columns_with_data.select_dtypes(include = ['object'])
categorical_features = categorical_data.columns.values
numerical_features = numerical_data.columns.values

# %%
print(dataset_columns_with_data.dtypes.to_dict())
# Out:
# {'dti': dtype('float64'), 'revol_bal': dtype('float64'), 'total_pymnt': dtype('float64'), 'total_rec_int': dtype('float64'), 'total_rec_late_fee': dtype('float64'), 'recoveries': dtype('float64'), 'last_pymnt_amnt': dtype('float64'), 'out_prncp': dtype('float64'), 'loan_amnt': dtype('float64'), 'int_rate': dtype('float64'), 'grade': dtype('int64'), 'sub_grade': dtype('int64'), 'annual_inc': dtype('float64'), 'acc_now_delinq': dtype('float64'), 'delinq_2yrs': dtype('float64'), 'pub_rec': dtype('float64'), 'open_acc': dtype('float64'), 'inq_last_6mths': dtype('float64'), 'collections_12_mths_ex_med': dtype('float64'), 'revol_util': dtype('float64'), 'emp_length': dtype('int64'), 'AL': dtype('uint8'), 'AR': dtype('uint8'), 'AZ': dtype('uint8'), 'CA': dtype('uint8'), 'CO': dtype('uint8'), 'CT': dtype('uint8'), 'DC': dtype('uint8'), 'DE': dtype('uint8'), 'FL': dtype('uint8'), 'GA': dtype('uint8'), 'HI': dtype('uint8'), 'IA': dtype('uint8'), 'ID': dtype('uint8'), 'IL': dtype('uint8'), 'IN': dtype('uint8'), 'KS': dtype('uint8'), 'KY': dtype('uint8'), 'LA': dtype('uint8'), 'MA': dtype('uint8'), 'MD': dtype('uint8'), 'ME': dtype('uint8'), 'MI': dtype('uint8'), 'MN': dtype('uint8'), 'MO': dtype('uint8'), 'MS': dtype('uint8'), 'MT': dtype('uint8'), 'NC': dtype('uint8'), 'ND': dtype('uint8'), 'NE': dtype('uint8'), 'NH': dtype('uint8'), 'NJ': dtype('uint8'), 'NM': dtype('uint8'), 'NV': dtype('uint8'), 'NY': dtype('uint8'), 'OH': dtype('uint8'), 'OK': dtype('uint8'), 'OR': dtype('uint8'), 'PA': dtype('uint8'), 'RI': dtype('uint8'), 'SC': dtype('uint8'), 'SD': dtype('uint8'), 'TN': dtype('uint8'), 'TX': dtype('uint8'), 'UT': dtype('uint8'), 'VA': dtype('uint8'), 'VT': dtype('uint8'), 'WA': dtype('uint8'), 'WI': dtype('uint8'), 'WV': dtype('uint8'), 'WY': dtype('uint8'), 'JOINT': dtype('uint8'), 'credit_card': dtype('uint8'), 'debt_consolidation': dtype('uint8'), 'educational': dtype('uint8'), 'home_improvement': dtype('uint8'), 'house': dtype('uint8'), 'major_purchase': dtype('uint8'), 'medical': dtype('uint8'), 'moving': dtype('uint8'), 'other': dtype('uint8'), 'renewable_energy': dtype('uint8'), 'small_business': dtype('uint8'), 'vacation': dtype('uint8'), 'wedding': dtype('uint8'), 'Source Verified': dtype('uint8'), 'Verified': dtype('uint8'), ' 60 months': dtype('uint8'), 'MORTGAGE': dtype('uint8'), 'NONE': dtype('uint8'), 'OTHER': dtype('uint8'), 'OWN': dtype('uint8'), 'RENT': dtype('uint8')}

# %%
print('Total number of features after handling categorical data: ',len(dataset_columns_with_data.columns.values))
print("No. of categorical features left:",len(categorical_features))
print("No. of Numerical features left:",len(numerical_features))
# Out:
# Total number of features after handling categorical data:  93
# No. of categorical features left: 0
# No. of Numerical features left: 93

# %%
dictfeatures=dataset_columns_with_data.corr()['int_rate'].sort_values(ascending=False).to_dict()

# %%
dictfeatures
# Out:
# {'int_rate': 1.0,
#  'sub_grade': 0.9774138265585272,
#  'grade': 0.9542282778301797,
#  'total_rec_int': 0.44577944941724107,
#  ' 60 months': 0.4281278597904553,
#  'revol_util': 0.2690783050521046,
#  'inq_last_6mths': 0.2279973418205078,
#  'Verified': 0.21123764547850013,
#  'total_pymnt': 0.1705737745728128,
#  'loan_amnt': 0.14505555856281035,
#  'recoveries': 0.10683142455710799,
#  'last_pymnt_amnt': 0.10119466653787286,
#  'debt_consolidation': 0.09736513310599197,
#  'other': 0.09130628950453423,
#  'dti': 0.07994412136514223,
#  'small_business': 0.07419330038931472,
#  'RENT': 0.061560544983168625,
#  'total_rec_late_fee': 0.05713169964608411,
#  'delinq_2yrs': 0.05510224806203673,
#  'pub_rec': 0.052216576190761574,
#  'moving': 0.04441230833395592,
#  'out_prncp': 0.04266835819687199,
#  'house': 0.04087411730115664,
#  'medical': 0.0294743516963035,
#  'acc_now_delinq': 0.02647986349882553,
#  'vacation': 0.01822399466394524,
#  'collections_12_mths_ex_med': 0.013357984714299834,
#  'AL': 0.01316797822715439,
#  'renewable_energy': 0.01247792526365143,
#  'HI': 0.011053392500383974,
#  'wedding': 0.01063607531256423,
#  'JOINT': 0.010553757104240781,
#  'TN': 0.009088601257302558,
#  'emp_length': 0.007868016701196216,
#  'NC': 0.00679261029737703,
#  'IN': 0.006255818112489287,
#  'NV': 0.006079431614994105,
#  'SC': 0.005742037002343742,
#  'NY': 0.005538565588259458,
#  'WA': 0.0052822536673920615,
#  'OK': 0.005017092383861638,
#  'MD': 0.004776613064959417,
#  'AR': 0.004178564182266473,
#  'PA': 0.0037408018172711047,
#  'OH': 0.0036132741427102005,
#  'MS': 0.00344098131382472,
#  'NONE': 0.0033336104316820285,
#  'LA': 0.0025340566358357255,
#  'DE': 0.002497726601964068,
#  'KY': 0.002092826701857265,
#  'Source Verified': 0.0020588097822489358,
#  'SD': 0.0019386119781104,
#  'UT': 0.001914485956928859,
#  'MI': 0.0018481778711026207,
#  'WV': 0.001751920337003332,
#  'VA': 0.0016332386652564903,
#  'FL': 0.0016118815622955032,
#  'OWN': 0.0013975986228930294,
#  'NM': 0.0013621141206994571,
#  'WY': 0.0013471025499698854,
#  'GA': 0.0010003682997077486,
#  'KS': 0.0007463904630201078,
#  'OTHER': 0.0007158708867002221,
#  'MO': -4.747807445704659e-05,
#  'IA': -0.0005572870264875714,
#  'ID': -0.001595281953116029,
#  'ND': -0.0018328615266959287,
#  'MT': -0.002151361602523953,
#  'NE': -0.002360293314003752,
#  'RI': -0.002424149037670256,
#  'OR': -0.0027033153931741633,
#  'VT': -0.002891047289205118,
#  'MN': -0.003028574435730452,
#  'AZ': -0.004046159155805637,
#  'ME': -0.004326368464340971,
#  'NJ': -0.004391444288169588,
#  'CT': -0.0050064450858974706,
#  'educational': -0.005653645856544775,
#  'CO': -0.005725132028974312,
#  'TX': -0.005798572277767709,
#  'DC': -0.005900720866982401,
#  'NH': -0.00624193334088101,
#  'WI': -0.006854721861415224,
#  'IL': -0.0070239957622475185,
#  'CA': -0.007993523960582921,
#  'open_acc': -0.010048049076040738,
#  'home_improvement': -0.012634685436634754,
#  'major_purchase': -0.018476768957257972,
#  'MA': -0.020520699848092468,
#  'revol_bal': -0.035603787502063285,
#  'MORTGAGE': -0.06125153172673287,
#  'annual_inc': -0.07284539620493903,
#  'credit_card': -0.18490376524216512}

# %%
final_clean_numeric_features=pd.DataFrame({"correlation with int_rate":dictfeatures})

# %%
final_clean_numeric_features.index.name="Feature name"

# %%
final_clean_numeric_features.to_csv('../Data/final_clean_numeric_features.csv')

# %%
dataset_columns_with_data.to_csv('../Data/dataset_columns_with_data.csv')

# %%
dataset_columns_with_data.describe()
# Out:
#                  dti     revol_bal    total_pymnt  total_rec_int  \
# count  886713.000000  8.867130e+05  886713.000000  886713.000000
# mean       18.160590  1.692467e+04    7559.273766    1755.001637
# std        17.194998  2.241267e+04    7871.557404    2095.479058
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%        11.910000  6.451000e+03    1914.530000     441.530000
# 50%        17.660000  1.188000e+04    4895.120000    1073.570000
# 75%        23.950000  2.083400e+04   10618.140000    2238.590000
# max      9999.000000  2.904836e+06   57777.579870   24205.620000
#
#        total_rec_late_fee     recoveries  last_pymnt_amnt      out_prncp  \
# count       886713.000000  886713.000000    886713.000000  886713.000000
# mean             0.395571      45.903508      2164.303781    8405.920818
# std              4.082276     409.677977      4794.738016    8493.410411
# min              0.000000       0.000000         0.000000       0.000000
# 25%              0.000000       0.000000       280.210000       0.000000
# 50%              0.000000       0.000000       462.840000    6466.100000
# 75%              0.000000       0.000000       831.230000   13660.920000
# max            358.680000   33520.270000     36475.590000   49372.860000
#
#            loan_amnt       int_rate      ...             vacation  \
# count  886713.000000  886713.000000      ...        886713.000000
# mean    14758.062755      13.245973      ...             0.005326
# std      8434.244175       4.381777      ...             0.072788
# min       500.000000       5.320000      ...             0.000000
# 25%      8000.000000       9.990000      ...             0.000000
# 50%     13000.000000      12.990000      ...             0.000000
# 75%     20000.000000      16.200000      ...             0.000000
# max     35000.000000      28.990000      ...             1.000000
#
#              wedding  Source Verified      Verified      60 months  \
# count  886713.000000    886713.000000  886713.00000  886713.000000
# mean        0.002643         0.371458       0.32804       0.300128
# std         0.051347         0.483195       0.46950       0.458313
# min         0.000000         0.000000       0.00000       0.000000
# 25%         0.000000         0.000000       0.00000       0.000000
# 50%         0.000000         0.000000       0.00000       0.000000
# 75%         0.000000         1.000000       1.00000       1.000000
# max         1.000000         1.000000       1.00000       1.000000
#
#             MORTGAGE           NONE          OTHER            OWN  \
# count  886713.000000  886713.000000  886713.000000  886713.000000
# mean        0.499879       0.000050       0.000203       0.098554
# std         0.500000       0.007044       0.014246       0.298062
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         1.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#                 RENT
# count  886713.000000
# mean        0.401311
# std         0.490164
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
#
# [8 rows x 93 columns]

# %%
dataset_columns_with_data_copy1 =dataset_columns_with_data

# %%
dataset_columns_with_data.shape
# Out:
# (886713, 93)

# %%
Q1, Q3= np.percentile(dataset_columns_with_data_copy1[numerical_data_outlierslist],[25,75])
IQR = Q3 - Q1
lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)

# %%
lower_bound
# Out:
# -1571.19

# %%
dataset_columns_with_data_out = (dataset_columns_with_data_copy1[numerical_data_outlierslist] < (q1 - 1.5 * iqr)) |(dataset_columns_with_data_copy1[numerical_data_outlierslist] > (q3 + 1.5 * iqr))

# %%
dataset_columns_with_data_out.describe()
# Out:
#            dti revol_bal total_pymnt total_rec_int total_rec_late_fee  \
# count   886713    886713      886713        886713             886713
# unique       2         2           2             2                  1
# top      False      True        True         False              False
# freq    886711    826179      600700        707210             886713
#
#        recoveries last_pymnt_amnt out_prncp loan_amnt int_rate    ...      \
# count      886713          886713    886713    886713   886713    ...
# unique          2               2         2         2        1    ...
# top         False           False      True      True    False    ...
# freq       881639          742530    577122    863926   886713    ...
#
#        sub_grade annual_inc acc_now_delinq delinq_2yrs pub_rec open_acc  \
# count     886713     886713         886713      886713  886713   886713
# unique         1          2              1           1       1        1
# top        False       True          False       False   False    False
# freq      886713     886707         886713      886713  886713   886713
#
#        inq_last_6mths collections_12_mths_ex_med revol_util emp_length
# count          886713                     886713     886713     886713
# unique              1                          1          1          1
# top             False                      False      False      False
# freq           886713                     886713     886713     886713
#
# [4 rows x 21 columns]

# %%
dataset_columns_with_data_copy2 = dataset_columns_with_data_copy1[~((dataset_columns_with_data_copy1[numerical_data_outlierslist] < (Q1 - 1.5 * IQR)) |(dataset_columns_with_data_copy1[numerical_data_outlierslist] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
dataset_columns_with_data_copy2
# Out:
#          dti  revol_bal  total_pymnt  total_rec_int  total_rec_late_fee  \
# 42362   0.00        0.0        83.88          14.44                 0.0
# 42437  18.99      702.0      2173.19         373.19                 0.0
#
#        recoveries  last_pymnt_amnt  out_prncp  loan_amnt  int_rate  ...   \
# 42362        20.4            15.90        0.0      500.0      9.01  ...
# 42437         0.0          1080.38        0.0     1800.0     17.22  ...
#
#        vacation  wedding  Source Verified  Verified   60 months  MORTGAGE  \
# 42362         0        0                0         0           0         0
# 42437         0        0                0         0           0         0
#
#        NONE  OTHER  OWN  RENT
# 42362     0      0    0     1
# 42437     0      0    0     1
#
# [2 rows x 93 columns]

# %%
dataset_columns_with_data_copy1=dataset_columns_with_data_copy1.loc[~(dataset_columns_with_data_out),:]

# %%
dataset_columns_with_data_copy1.shape
# Out:
# (886713, 93)

# %%
numerical_data_outliers = dataset_columns_with_data.select_dtypes(include = ['int64','float'])

# %%
numerical_data_outlierslist=numerical_data_outliers.columns.values.tolist()

# %%
dataset_columns_with_data_out.shape
# Out:
# (886713, 21)

# %%
dataset_columns_with_data_out_copy1 = dataset_columns_with_data_out[(dataset_columns_with_data_out != True).any(axis=1)]

# %%
out = dataset_columns_with_data_out.replace({'True': np.nan}).dropna().astype(float)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-449-62e212c4e62c> in <module>
#       1
# ----> 2 out = dataset_columns_with_data_out.replace({'True': np.nan}).dropna().astype(float)
#
# TypeError: replace() takes at least 2 arguments (1 given)

# %%
out
# Out:
#          dti revol_bal total_pymnt total_rec_int total_rec_late_fee  \
# 42362  False     False       False         False              False
# 42437  False     False       False         False              False
#
#       recoveries last_pymnt_amnt out_prncp loan_amnt int_rate    ...      \
# 42362      False           False     False     False    False    ...
# 42437      False           False     False     False    False    ...
#
#       sub_grade annual_inc acc_now_delinq delinq_2yrs pub_rec open_acc  \
# 42362     False      False          False       False   False    False
# 42437     False      False          False       False   False    False
#
#       inq_last_6mths collections_12_mths_ex_med revol_util emp_length
# 42362          False                      False      False      False
# 42437          False                      False      False      False
#
# [2 rows x 21 columns]

# %%
q1, q3= np.percentile(dataset_columns_with_data_copy1[numerical_data_outliers],[25,75])
iqr = q3 - q1
lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)
dataset_columns_with_data_out = (dataset_columns_with_data_copy1[numerical_data_outliers] < (q1 - 1.5 * iqr)) |(dataset_columns_with_data_copy1[numerical_data_outliers] > (q3 + 1.5 * iqr))

# %%
dataset_columns_with_data_out.apply()
for each in numerical_data_outliers:
    print(dataset_columns_with_data_out[each].value_counts())
