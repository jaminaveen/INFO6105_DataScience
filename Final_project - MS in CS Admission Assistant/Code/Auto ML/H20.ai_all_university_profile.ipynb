# %% [markdown]
# # This Notebook Covers:
# - Auto ML using H2o.ai
# - H2o.ai has been run on the cleaned information of profiles of admit/reject of students for 29 Universities for CS students
# - Error metrices have been calculated for H2o.ai classification models
# - Summarization of Model below

# %%
import pandas as pd
import h2o
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve,auc

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) 64-Bit Server VM (build 25.201-b09, mixed mode)
#   Starting server from C:\Users\navee\Anaconda3\lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\navee\AppData\Local\Temp\tmpo1_mejia
#   JVM stdout: C:\Users\navee\AppData\Local\Temp\tmpo1_mejia\h2o_navee_started_from_python.out
#   JVM stderr: C:\Users\navee\AppData\Local\Temp\tmpo1_mejia\h2o_navee_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ------------------------------------------
# H2O cluster uptime:         02 secs
# H2O cluster timezone:       America/New_York
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.24.0.1
# H2O cluster version age:    20 days
# H2O cluster name:           H2O_from_python_navee_kunjd4
# H2O cluster total nodes:    1
# H2O cluster free memory:    3.500 Gb
# H2O cluster total cores:    12
# H2O cluster allowed cores:  12
# H2O cluster status:         accepting new members, healthy
# H2O connection url:         http://127.0.0.1:54321
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         Amazon S3, Algos, AutoML, Core V3, Core V4
# Python version:             3.7.1 final
# --------------------------  ------------------------------------------

# %%
# Reading dataset from Data Folder
dataset = pd.read_csv('../../Data/clean_profile_data_all.csv')

# %%
dataset.head()
# Out:
#    gre_score  gre_score_quant  gre_score_verbal  test_score_toefl  \
# 0        316              164               152             106.0
# 1        314              163               151             114.0
# 2        307              160               147              88.0
# 3        330              169               161             113.0
# 4        316              163               153              99.0
#
#    undergraduation_score  work_ex  papers_published          university_name  \
# 0                   2.90        9                 3  northeastern_university
# 1                   3.53        7                 3  northeastern_university
# 2                   3.00       36                 0  northeastern_university
# 3                   2.40       48                 3  northeastern_university
# 4                   2.71       30                 0  northeastern_university
#
#    status  ranking
# 0  accept       15
# 1  accept       15
# 2  accept       15
# 3  accept       15
# 4  accept       15

# %%
#making a stratified split on university name and status to have all scenarios in train and test dataset
train,test = train_test_split(dataset, test_size=0.30, random_state=0,stratify=dataset[['university_name', 'status']])

# %%
#checking train test split
train.groupby(by=['university_name'])['status'].value_counts()
# Out:
# university_name                              status
# carnegie_mellon_university                   reject     87
#                                              accept     26
# clemson_university                           accept     57
#                                              reject     28
# george_mason_university                      accept    118
#                                              reject     67
# georgia_institiute_of_technology             accept     61
#                                              reject     28
# illinois_institute_of_technology             accept    188
#                                              reject    117
# indiana_university_bloomington               accept    190
#                                              reject     50
# kansas_state_university                      accept     31
#                                              reject     22
# michigan_technological_university            accept     71
#                                              reject     26
# new_york_university                          reject    125
#                                              accept     97
# north_carolina_state_university_raleigh      reject    215
#                                              accept    197
# northeastern_university                      reject    755
#                                              accept    402
# rochester_institute_of_technology            accept    142
#                                              reject     97
# rutgers_university_new_brunswick             reject    137
#                                              accept     76
# state_university_of_new_york_at_stony_brook  reject    225
#                                              accept    197
# syracuse_university                          reject    196
#                                              accept    167
# texas_a_m_university_college_station         reject    155
#                                              accept    116
# university_of_california_irvine              reject    200
#                                              accept     80
# university_of_cincinnati                     accept    140
#                                              reject     29
# university_of_colorado_boulder               reject    136
#                                              accept    102
# university_of_connecticut                    accept     27
#                                              reject     18
# university_of_florida                        accept     42
#                                              reject     24
# university_of_iowa                           accept     30
#                                              reject     11
# university_of_maryland_college_park          reject    162
#                                              accept     22
# university_of_north_carolina_at_charlotte    reject    136
#                                              accept    130
# university_of_southern_california            accept     20
#                                              reject      7
# university_of_texas_arlington                accept    125
#                                              reject     94
# university_of_texas_austin                   reject    154
#                                              accept      9
# university_of_texas_dallas                   reject    172
#                                              accept    160
# worcester_polytechnic_institute              reject     26
#                                              accept     23
# Name: status, dtype: int64

# %%
test.groupby(by=['university_name'])['status'].value_counts()
# Out:
# university_name                              status
# carnegie_mellon_university                   reject     38
#                                              accept     11
# clemson_university                           accept     25
#                                              reject     12
# george_mason_university                      accept     50
#                                              reject     29
# georgia_institiute_of_technology             accept     26
#                                              reject     12
# illinois_institute_of_technology             accept     80
#                                              reject     50
# indiana_university_bloomington               accept     81
#                                              reject     22
# kansas_state_university                      accept     13
#                                              reject     10
# michigan_technological_university            accept     30
#                                              reject     11
# new_york_university                          reject     54
#                                              accept     42
# north_carolina_state_university_raleigh      reject     92
#                                              accept     84
# northeastern_university                      reject    324
#                                              accept    172
# rochester_institute_of_technology            accept     61
#                                              reject     41
# rutgers_university_new_brunswick             reject     59
#                                              accept     32
# state_university_of_new_york_at_stony_brook  reject     96
#                                              accept     84
# syracuse_university                          reject     84
#                                              accept     71
# texas_a_m_university_college_station         reject     66
#                                              accept     50
# university_of_california_irvine              reject     86
#                                              accept     34
# university_of_cincinnati                     accept     60
#                                              reject     13
# university_of_colorado_boulder               reject     59
#                                              accept     44
# university_of_connecticut                    accept     11
#                                              reject      8
# university_of_florida                        accept     18
#                                              reject     11
# university_of_iowa                           accept     13
#                                              reject      5
# university_of_maryland_college_park          reject     70
#                                              accept     10
# university_of_north_carolina_at_charlotte    reject     59
#                                              accept     55
# university_of_southern_california            accept      8
#                                              reject      3
# university_of_texas_arlington                accept     53
#                                              reject     40
# university_of_texas_austin                   reject     66
#                                              accept      4
# university_of_texas_dallas                   reject     73
#                                              accept     69
# worcester_polytechnic_institute              reject     11
#                                              accept     10
# Name: status, dtype: int64

# %%
train.to_csv('../../Data/alldata_train.csv',index=False)
test.to_csv('../../Data/alldata_test.csv',index=False)

# %%
train['status']
# Out:
# 7449    accept
# 3087    reject
# 3102    accept
# 2697    accept
# 4915    accept
# 4890    accept
# 3518    reject
# 1020    accept
# 6894    reject
# 5400    accept
# 4386    reject
# 1419    accept
# 3607    reject
# 9291    accept
# 5674    reject
# 3692    reject
# 5227    accept
# 8785    reject
# 4880    accept
# 2381    accept
# 7405    reject
# 391     accept
# 5812    accept
# 2538    accept
# 4589    accept
# 9329    reject
# 4409    reject
# 3027    reject
# 6518    reject
# 2324    reject
#          ...
# 6520    reject
# 1550    reject
# 2150    reject
# 7418    reject
# 1329    accept
# 5405    accept
# 4735    reject
# 5774    accept
# 6590    reject
# 4353    reject
# 4218    reject
# 4489    reject
# 6952    reject
# 77      accept
# 3181    accept
# 4746    reject
# 6147    reject
# 5002    reject
# 1963    reject
# 9143    accept
# 4064    reject
# 8071    accept
# 2037    accept
# 5535    reject
# 1175    accept
# 8146    reject
# 1206    accept
# 7531    reject
# 4270    reject
# 1004    accept
# Name: status, Length: 6545, dtype: object

# %%
train_frame= h2o.import_file('../Data/alldata_train.csv')
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
training_columns=train.columns.tolist()
response_column='status'

# %%
training_columns
# Out:
# ['gre_score',
#  'gre_score_quant',
#  'gre_score_verbal',
#  'test_score_toefl',
#  'undergraduation_score',
#  'work_ex',
#  'papers_published',
#  'university_name',
#  'status',
#  'ranking']

# %%
from h2o.automl import H2OAutoML

# %%
model = H2OAutoML(max_models=20, seed=1)
model.train(x=training_columns, y=response_column, training_frame=train_frame)
# Out:
# AutoML progress: |████████████████████████████████████████████████████████| 100%

# %%
# best models after the H2o.ai model creation
model.leaderboard
# Out:
# <table>
# <thead>
# <tr><th>model_id                                           </th><th style="text-align: right;">     auc</th><th style="text-align: right;">  logloss</th><th style="text-align: right;">  mean_per_class_error</th><th style="text-align: right;">    rmse</th><th style="text-align: right;">     mse</th></tr>
# </thead>
# <tbody>
# <tr><td>StackedEnsemble_AllModels_AutoML_20190421_184847   </td><td style="text-align: right;">0.812672</td><td style="text-align: right;"> 0.528106</td><td style="text-align: right;">              0.295999</td><td style="text-align: right;">0.420016</td><td style="text-align: right;">0.176414</td></tr>
# <tr><td>StackedEnsemble_BestOfFamily_AutoML_20190421_184847</td><td style="text-align: right;">0.812144</td><td style="text-align: right;"> 0.528744</td><td style="text-align: right;">              0.299218</td><td style="text-align: right;">0.420207</td><td style="text-align: right;">0.176574</td></tr>
# <tr><td>GBM_2_AutoML_20190421_184847                       </td><td style="text-align: right;">0.804539</td><td style="text-align: right;"> 0.535684</td><td style="text-align: right;">              0.307208</td><td style="text-align: right;">0.423929</td><td style="text-align: right;">0.179716</td></tr>
# <tr><td>GBM_4_AutoML_20190421_184847                       </td><td style="text-align: right;">0.802918</td><td style="text-align: right;"> 0.539849</td><td style="text-align: right;">              0.304104</td><td style="text-align: right;">0.425273</td><td style="text-align: right;">0.180857</td></tr>
# <tr><td>GBM_grid_1_AutoML_20190421_184847_model_1          </td><td style="text-align: right;">0.802622</td><td style="text-align: right;"> 0.573579</td><td style="text-align: right;">              0.302213</td><td style="text-align: right;">0.439663</td><td style="text-align: right;">0.193304</td></tr>
# <tr><td>GBM_1_AutoML_20190421_184847                       </td><td style="text-align: right;">0.802595</td><td style="text-align: right;"> 0.538182</td><td style="text-align: right;">              0.299901</td><td style="text-align: right;">0.425092</td><td style="text-align: right;">0.180703</td></tr>
# <tr><td>GBM_3_AutoML_20190421_184847                       </td><td style="text-align: right;">0.802074</td><td style="text-align: right;"> 0.539119</td><td style="text-align: right;">              0.295257</td><td style="text-align: right;">0.425336</td><td style="text-align: right;">0.180911</td></tr>
# <tr><td>GBM_grid_1_AutoML_20190421_184847_model_4          </td><td style="text-align: right;">0.799797</td><td style="text-align: right;"> 0.60856 </td><td style="text-align: right;">              0.301139</td><td style="text-align: right;">0.456945</td><td style="text-align: right;">0.208799</td></tr>
# <tr><td>GBM_5_AutoML_20190421_184847                       </td><td style="text-align: right;">0.798158</td><td style="text-align: right;"> 0.544081</td><td style="text-align: right;">              0.312369</td><td style="text-align: right;">0.427603</td><td style="text-align: right;">0.182844</td></tr>
# <tr><td>DRF_1_AutoML_20190421_184847                       </td><td style="text-align: right;">0.797656</td><td style="text-align: right;"> 0.597633</td><td style="text-align: right;">              0.300892</td><td style="text-align: right;">0.428133</td><td style="text-align: right;">0.183297</td></tr>
# </tbody>
# </table>

# %%
model_path = h2o.save_model(model=model.leader, path="/Models", force=True)

# %%
model.leader
# Out:
# Model Details
# =============
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_AllModels_AutoML_20190421_184847
# No model summary for this model
#
#
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.069251420250454
# RMSE: 0.26315664584132015
# LogLoss: 0.27307622908116075
# Null degrees of freedom: 6544
# Residual degrees of freedom: 6534
# Null deviance: 9041.917960125375
# Residual deviance: 3574.567838672394
# AIC: 3596.567838672394
# AUC: 0.9904133100968535
# pr_auc: 0.9913636370837298
# Gini: 0.980826620193707
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.5424340682214746:
#         accept    reject    Error    Rate
# ------  --------  --------  -------  --------------
# accept  2894      152       0.0499   (152.0/3046.0)
# reject  194       3305      0.0554   (194.0/3499.0)
# Total   3088      3457      0.0529   (346.0/6545.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.542434     0.950259  188
# max f2                       0.416904     0.96429   234
# max f0point5                 0.61818      0.963588  161
# max accuracy                 0.542434     0.947135  188
# max precision                0.933715     1         0
# max recall                   0.228597     1         311
# max specificity              0.933715     1         0
# max absolute_mcc             0.542434     0.89393   188
# max min_per_class_accuracy   0.534943     0.945985  191
# max mean_per_class_accuracy  0.542434     0.947327  188
# Gains/Lift Table: Avg response rate: 53.46 %, avg score: 53.59 %
#     group    cumulative_data_fraction    lower_threshold    lift        cumulative_lift    response_rate    score      cumulative_response_rate    cumulative_score    capture_rate    cumulative_capture_rate    gain      cumulative_gain
# --  -------  --------------------------  -----------------  ----------  -----------------  ---------------  ---------  --------------------------  ------------------  --------------  -------------------------  --------  -----------------
#     1        0.010084                    0.924056           1.87053     1.87053            1                0.92709    1                           0.92709             0.0188625       0.0188625                  87.0534   87.0534
#     2        0.0201681                   0.92056            1.87053     1.87053            1                0.922281   1                           0.924685            0.0188625       0.0377251                  87.0534   87.0534
#     3        0.0300993                   0.917434           1.87053     1.87053            1                0.918971   1                           0.9228              0.0185767       0.0563018                  87.0534   87.0534
#     4        0.0400306                   0.914559           1.87053     1.87053            1                0.915757   1                           0.921053            0.0185767       0.0748785                  87.0534   87.0534
#     5        0.0501146                   0.91181            1.87053     1.87053            1                0.913209   1                           0.919474            0.0188625       0.0937411                  87.0534   87.0534
#     6        0.100076                    0.899621           1.87053     1.87053            1                0.905931   1                           0.912713            0.0934553       0.187196                   87.0534   87.0534
#     7        0.150038                    0.88575            1.87053     1.87053            1                0.892772   1                           0.906073            0.0934553       0.280652                   87.0534   87.0534
#     8        0.2                         0.867982           1.87053     1.87053            1                0.877493   1                           0.898933            0.0934553       0.374107                   87.0534   87.0534
#     9        0.300076                    0.810783           1.87053     1.87053            1                0.842023   1                           0.879953            0.187196        0.561303                   87.0534   87.0534
#     10       0.4                         0.730849           1.85337     1.86625            0.990826         0.771111   0.997708                    0.852764            0.185196        0.746499                   85.3374   86.6247
#     11       0.500076                    0.593534           1.6535      1.82367            0.883969         0.669916   0.974947                    0.816172            0.165476        0.911975                   65.3495   82.3671
#     12       0.6                         0.409642           0.752218    1.64523            0.402141         0.4983     0.879552                    0.763234            0.0751643       0.987139                   -24.7782  64.5232
#     13       0.699924                    0.267977           0.122986    1.42791            0.0657492        0.33546    0.76337                     0.702163            0.0122892       0.999428                   -87.7014  42.7911
#     14       0.8                         0.17247            0.00571156  1.25               0.00305344       0.216546   0.668258                    0.641415            0.000571592     1                          -99.4288  25
#     15       0.900076                    0.11022            0           1.11102            0                0.138896   0.593957                    0.585541            0               1                          -100      11.1017
#     16       1                           0.0649784          0           1                  0                0.0885511  0.534607                    0.53588             0               1                          -100      0
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.17641379695252904
# RMSE: 0.4200164246223343
# LogLoss: 0.5281059346438636
# Null degrees of freedom: 6544
# Residual degrees of freedom: 6534
# Null deviance: 9042.29006860386
# Residual deviance: 6912.9066844881745
# AIC: 6934.9066844881745
# AUC: 0.8126723947204126
# pr_auc: 0.819777143506489
# Gini: 0.6253447894408253
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.33120457784825164:
#         accept    reject    Error    Rate
# ------  --------  --------  -------  ---------------
# accept  1564      1482      0.4865   (1482.0/3046.0)
# reject  369       3130      0.1055   (369.0/3499.0)
# Total   1933      4612      0.2828   (1851.0/6545.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.331205     0.771791  280
# max f2                       0.199755     0.86735   335
# max f0point5                 0.664241     0.760367  137
# max accuracy                 0.499026     0.738732  207
# max precision                0.9251       0.96      1
# max recall                   0.0756862    1         395
# max specificity              0.927674     0.999672  0
# max absolute_mcc             0.499026     0.473803  207
# max min_per_class_accuracy   0.542177     0.735062  189
# max mean_per_class_accuracy  0.539631     0.736631  190
# Gains/Lift Table: Avg response rate: 53.46 %, avg score: 53.43 %
#     group    cumulative_data_fraction    lower_threshold    lift      cumulative_lift    response_rate    score     cumulative_response_rate    cumulative_score    capture_rate    cumulative_capture_rate    gain      cumulative_gain
# --  -------  --------------------------  -----------------  --------  -----------------  ---------------  --------  --------------------------  ------------------  --------------  -------------------------  --------  -----------------
#     1        0.010084                    0.919406           1.72883   1.72883            0.924242         0.92335   0.924242                    0.92335             0.0174336       0.0174336                  72.8827   72.8827
#     2        0.0200153                   0.912612           1.69787   1.71347            0.907692         0.916236  0.916031                    0.91982             0.016862        0.0342955                  69.787    71.3467
#     3        0.0300993                   0.907597           1.81385   1.7471             0.969697         0.90991   0.93401                     0.9165              0.0182909       0.0525865                  81.3852   74.7098
#     4        0.0400306                   0.903047           1.69787   1.73488            0.907692         0.905237  0.927481                    0.913706            0.016862        0.0694484                  69.787    73.4885
#     5        0.0501146                   0.899593           1.72883   1.73367            0.924242         0.901267  0.926829                    0.911203            0.0174336       0.086882                   72.8827   73.3666
#     6        0.100076                    0.879749           1.73897   1.73631            0.929664         0.889866  0.928244                    0.900551            0.086882        0.173764                   73.8968   73.6313
#     7        0.150038                    0.856113           1.64744   1.70672            0.880734         0.868489  0.912424                    0.889875            0.0823092       0.256073                   64.7443   70.672
#     8        0.2                         0.828145           1.60168   1.68048            0.856269         0.842724  0.898396                    0.878096            0.0800229       0.336096                   60.1681   68.048
#     9        0.300076                    0.755523           1.40219   1.58767            0.749618         0.79333   0.848778                    0.849826            0.140326        0.476422                   40.2187   58.7668
#     10       0.4                         0.667762           1.30423   1.51686            0.697248         0.713101  0.810924                    0.815671            0.130323        0.606745                   30.4226   51.6862
#     11       0.500076                    0.560648           1.11946   1.43733            0.598473         0.614881  0.768408                    0.775489            0.112032        0.718777                   11.9465   43.7334
#     12       0.6                         0.44545            0.909526  1.34943            0.486239         0.504885  0.721416                    0.730423            0.0908831       0.80966                    -9.04741  34.9433
#     13       0.699924                    0.33369            0.806561  1.27193            0.431193         0.388695  0.679983                    0.681636            0.0805945       0.890254                   -19.3439  27.1931
#     14       0.8                         0.229036           0.565444  1.18355            0.30229          0.279636  0.632735                    0.631348            0.0565876       0.946842                   -43.4556  18.3552
#     15       0.899924                    0.144169           0.368959  1.0931             0.197248         0.183551  0.58438                     0.581626            0.0368677       0.98371                    -63.1041  9.31035
#     16       1                           0.0625367          0.162779  1                  0.0870229        0.108764  0.534607                    0.534304            0.0162904       1                          -83.7221  0

# %%
saved_model = h2o.load_model(model_path)

# %%
saved_model
# Out:
# Model Details
# =============
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_AllModels_AutoML_20190421_184847
# No model summary for this model
#
#
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.069251420250454
# RMSE: 0.26315664584132015
# LogLoss: 0.27307622908116075
# Null degrees of freedom: 6544
# Residual degrees of freedom: 6534
# Null deviance: 9041.917960125375
# Residual deviance: 3574.567838672394
# AIC: 3596.567838672394
# AUC: 0.9904133100968535
# pr_auc: 0.9913636370837298
# Gini: 0.980826620193707
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.5424340682214746:
#         accept    reject    Error    Rate
# ------  --------  --------  -------  --------------
# accept  2894      152       0.0499   (152.0/3046.0)
# reject  194       3305      0.0554   (194.0/3499.0)
# Total   3088      3457      0.0529   (346.0/6545.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.542434     0.950259  188
# max f2                       0.416904     0.96429   234
# max f0point5                 0.61818      0.963588  161
# max accuracy                 0.542434     0.947135  188
# max precision                0.933715     1         0
# max recall                   0.228597     1         311
# max specificity              0.933715     1         0
# max absolute_mcc             0.542434     0.89393   188
# max min_per_class_accuracy   0.534943     0.945985  191
# max mean_per_class_accuracy  0.542434     0.947327  188
# Gains/Lift Table: Avg response rate: 53.46 %, avg score: 53.59 %
#     group    cumulative_data_fraction    lower_threshold    lift        cumulative_lift    response_rate    score      cumulative_response_rate    cumulative_score    capture_rate    cumulative_capture_rate    gain      cumulative_gain
# --  -------  --------------------------  -----------------  ----------  -----------------  ---------------  ---------  --------------------------  ------------------  --------------  -------------------------  --------  -----------------
#     1        0.010084                    0.924056           1.87053     1.87053            1                0.92709    1                           0.92709             0.0188625       0.0188625                  87.0534   87.0534
#     2        0.0201681                   0.92056            1.87053     1.87053            1                0.922281   1                           0.924685            0.0188625       0.0377251                  87.0534   87.0534
#     3        0.0300993                   0.917434           1.87053     1.87053            1                0.918971   1                           0.9228              0.0185767       0.0563018                  87.0534   87.0534
#     4        0.0400306                   0.914559           1.87053     1.87053            1                0.915757   1                           0.921053            0.0185767       0.0748785                  87.0534   87.0534
#     5        0.0501146                   0.91181            1.87053     1.87053            1                0.913209   1                           0.919474            0.0188625       0.0937411                  87.0534   87.0534
#     6        0.100076                    0.899621           1.87053     1.87053            1                0.905931   1                           0.912713            0.0934553       0.187196                   87.0534   87.0534
#     7        0.150038                    0.88575            1.87053     1.87053            1                0.892772   1                           0.906073            0.0934553       0.280652                   87.0534   87.0534
#     8        0.2                         0.867982           1.87053     1.87053            1                0.877493   1                           0.898933            0.0934553       0.374107                   87.0534   87.0534
#     9        0.300076                    0.810783           1.87053     1.87053            1                0.842023   1                           0.879953            0.187196        0.561303                   87.0534   87.0534
#     10       0.4                         0.730849           1.85337     1.86625            0.990826         0.771111   0.997708                    0.852764            0.185196        0.746499                   85.3374   86.6247
#     11       0.500076                    0.593534           1.6535      1.82367            0.883969         0.669916   0.974947                    0.816172            0.165476        0.911975                   65.3495   82.3671
#     12       0.6                         0.409642           0.752218    1.64523            0.402141         0.4983     0.879552                    0.763234            0.0751643       0.987139                   -24.7782  64.5232
#     13       0.699924                    0.267977           0.122986    1.42791            0.0657492        0.33546    0.76337                     0.702163            0.0122892       0.999428                   -87.7014  42.7911
#     14       0.8                         0.17247            0.00571156  1.25               0.00305344       0.216546   0.668258                    0.641415            0.000571592     1                          -99.4288  25
#     15       0.900076                    0.11022            0           1.11102            0                0.138896   0.593957                    0.585541            0               1                          -100      11.1017
#     16       1                           0.0649784          0           1                  0                0.0885511  0.534607                    0.53588             0               1                          -100      0
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.17641379695252904
# RMSE: 0.4200164246223343
# LogLoss: 0.5281059346438636
# Null degrees of freedom: 6544
# Residual degrees of freedom: 6534
# Null deviance: 9042.29006860386
# Residual deviance: 6912.9066844881745
# AIC: 6934.9066844881745
# AUC: 0.8126723947204126
# pr_auc: 0.819777143506489
# Gini: 0.6253447894408253
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.33120457784825164:
#         accept    reject    Error    Rate
# ------  --------  --------  -------  ---------------
# accept  1564      1482      0.4865   (1482.0/3046.0)
# reject  369       3130      0.1055   (369.0/3499.0)
# Total   1933      4612      0.2828   (1851.0/6545.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.331205     0.771791  280
# max f2                       0.199755     0.86735   335
# max f0point5                 0.664241     0.760367  137
# max accuracy                 0.499026     0.738732  207
# max precision                0.9251       0.96      1
# max recall                   0.0756862    1         395
# max specificity              0.927674     0.999672  0
# max absolute_mcc             0.499026     0.473803  207
# max min_per_class_accuracy   0.542177     0.735062  189
# max mean_per_class_accuracy  0.539631     0.736631  190
# Gains/Lift Table: Avg response rate: 53.46 %, avg score: 53.43 %
#     group    cumulative_data_fraction    lower_threshold    lift      cumulative_lift    response_rate    score     cumulative_response_rate    cumulative_score    capture_rate    cumulative_capture_rate    gain      cumulative_gain
# --  -------  --------------------------  -----------------  --------  -----------------  ---------------  --------  --------------------------  ------------------  --------------  -------------------------  --------  -----------------
#     1        0.010084                    0.919406           1.72883   1.72883            0.924242         0.92335   0.924242                    0.92335             0.0174336       0.0174336                  72.8827   72.8827
#     2        0.0200153                   0.912612           1.69787   1.71347            0.907692         0.916236  0.916031                    0.91982             0.016862        0.0342955                  69.787    71.3467
#     3        0.0300993                   0.907597           1.81385   1.7471             0.969697         0.90991   0.93401                     0.9165              0.0182909       0.0525865                  81.3852   74.7098
#     4        0.0400306                   0.903047           1.69787   1.73488            0.907692         0.905237  0.927481                    0.913706            0.016862        0.0694484                  69.787    73.4885
#     5        0.0501146                   0.899593           1.72883   1.73367            0.924242         0.901267  0.926829                    0.911203            0.0174336       0.086882                   72.8827   73.3666
#     6        0.100076                    0.879749           1.73897   1.73631            0.929664         0.889866  0.928244                    0.900551            0.086882        0.173764                   73.8968   73.6313
#     7        0.150038                    0.856113           1.64744   1.70672            0.880734         0.868489  0.912424                    0.889875            0.0823092       0.256073                   64.7443   70.672
#     8        0.2                         0.828145           1.60168   1.68048            0.856269         0.842724  0.898396                    0.878096            0.0800229       0.336096                   60.1681   68.048
#     9        0.300076                    0.755523           1.40219   1.58767            0.749618         0.79333   0.848778                    0.849826            0.140326        0.476422                   40.2187   58.7668
#     10       0.4                         0.667762           1.30423   1.51686            0.697248         0.713101  0.810924                    0.815671            0.130323        0.606745                   30.4226   51.6862
#     11       0.500076                    0.560648           1.11946   1.43733            0.598473         0.614881  0.768408                    0.775489            0.112032        0.718777                   11.9465   43.7334
#     12       0.6                         0.44545            0.909526  1.34943            0.486239         0.504885  0.721416                    0.730423            0.0908831       0.80966                    -9.04741  34.9433
#     13       0.699924                    0.33369            0.806561  1.27193            0.431193         0.388695  0.679983                    0.681636            0.0805945       0.890254                   -19.3439  27.1931
#     14       0.8                         0.229036           0.565444  1.18355            0.30229          0.279636  0.632735                    0.631348            0.0565876       0.946842                   -43.4556  18.3552
#     15       0.899924                    0.144169           0.368959  1.0931             0.197248         0.183551  0.58438                     0.581626            0.0368677       0.98371                    -63.1041  9.31035
#     16       1                           0.0625367          0.162779  1                  0.0870229        0.108764  0.534607                    0.534304            0.0162904       1                          -83.7221  0

# %%
test_frame= h2o.import_file('../Data/alldata_test.csv')
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
predictions=saved_model.predict(test_frame)
# Out:
# stackedensemble prediction progress: |████████████████████████████████████| 100%

# %%
predictions.as_data_frame()
# Out:
#      predict    accept    reject
# 0     accept  0.785016  0.214984
# 1     reject  0.552952  0.447048
# 2     reject  0.457722  0.542278
# 3     reject  0.468964  0.531036
# 4     accept  0.696072  0.303928
# 5     reject  0.092059  0.907941
# 6     reject  0.633711  0.366289
# 7     reject  0.132787  0.867213
# 8     reject  0.161567  0.838433
# 9     accept  0.652721  0.347279
# 10    reject  0.082209  0.917791
# 11    accept  0.880706  0.119294
# 12    accept  0.797893  0.202107
# 13    accept  0.925595  0.074405
# 14    reject  0.248912  0.751088
# 15    accept  0.724742  0.275258
# 16    accept  0.648450  0.351550
# 17    accept  0.694238  0.305762
# 18    reject  0.450002  0.549998
# 19    reject  0.143640  0.856360
# 20    reject  0.397954  0.602046
# 21    reject  0.470288  0.529712
# 22    accept  0.852944  0.147056
# 23    reject  0.231966  0.768034
# 24    accept  0.837571  0.162429
# 25    reject  0.107714  0.892286
# 26    reject  0.532637  0.467363
# 27    accept  0.694032  0.305968
# 28    reject  0.353892  0.646108
# 29    reject  0.244753  0.755247
# ...      ...       ...       ...
# 2775  accept  0.911465  0.088535
# 2776  reject  0.154867  0.845133
# 2777  reject  0.424140  0.575860
# 2778  reject  0.224565  0.775435
# 2779  reject  0.146739  0.853261
# 2780  accept  0.801536  0.198464
# 2781  accept  0.710091  0.289909
# 2782  reject  0.101808  0.898192
# 2783  reject  0.305769  0.694231
# 2784  accept  0.766522  0.233478
# 2785  reject  0.333561  0.666439
# 2786  reject  0.375801  0.624199
# 2787  reject  0.148879  0.851121
# 2788  reject  0.463662  0.536338
# 2789  reject  0.493183  0.506817
# 2790  accept  0.872509  0.127491
# 2791  reject  0.305583  0.694417
# 2792  reject  0.097504  0.902496
# 2793  reject  0.144373  0.855627
# 2794  reject  0.592661  0.407339
# 2795  accept  0.833867  0.166133
# 2796  reject  0.446802  0.553198
# 2797  reject  0.195117  0.804883
# 2798  reject  0.122865  0.877135
# 2799  reject  0.204369  0.795631
# 2800  accept  0.877443  0.122557
# 2801  reject  0.396457  0.603543
# 2802  accept  0.808824  0.191176
# 2803  reject  0.222273  0.777727
# 2804  reject  0.222146  0.777854
#
# [2805 rows x 3 columns]

# %%
test
# Out:
#       gre_score  gre_score_quant  gre_score_verbal  test_score_toefl  \
# 8074        306              162               144             101.0
# 1459        305              161               144              99.0
# 502         320              164               156             113.0
# 1324        296              150               146              95.0
# 4883        320              170               150             108.0
# 8486        329              170               159             114.0
# 2020        311              163               148              91.0
# 7116        308              159               149             107.0
# 4213        307              161               146             104.0
# 4840        324              170               154             106.0
# 8910        305              157               148              90.0
# 2994        322              168               154             109.0
# 6786        317              164               153             107.0
# 9148        304              158               146              95.0
# 8852        307              161               146             101.0
# 8535        312              157               155              94.0
# 1774        315              166               149             101.0
# 1701        310              161               149             100.0
# 42          312              161               151             108.0
# 2764        316              161               155             114.0
# 7886        314              157               157             110.0
# 7538        314              160               154             112.0
# 2449        306              159               147              88.0
# 7955        318              170               148             112.0
# 1396        320              164               156             114.0
# 631         318              166               152             103.0
# 3210        326              170               156             110.0
# 150         329              166               163             114.0
# 404         309              163               146             101.0
# 6162        319              161               158             110.0
# ...         ...              ...               ...               ...
# 8617        325              169               156             100.0
# 6578        322              165               157             104.0
# 6307        321              166               155             106.0
# 575         328              167               161             117.0
# 718         325              170               155             110.0
# 6843        310              162               148             111.0
# 980         311              162               149             100.0
# 2899        314              160               154             107.0
# 605         323              166               157             112.0
# 6303        323              167               156             107.0
# 5226        321              164               157             112.0
# 2877        316              164               152             108.0
# 2108        314              163               151             104.0
# 4367        322              166               156             113.0
# 3773        307              160               147             111.0
# 1334        320              160               160             116.0
# 6249        310              161               149              94.0
# 5646        312              161               151              98.0
# 6038        314              157               157             110.0
# 3258        324              169               155             108.0
# 1787        320              160               160               0.0
# 549         315              152               163             106.0
# 2982        321              163               158              75.0
# 4065        312              161               151              95.0
# 3340        308              164               144              94.0
# 4541        309              160               149             104.0
# 2841        324              168               156             105.0
# 5297        325              167               158             115.0
# 6561        319              163               156             109.0
# 5191        315              162               153              75.0
#
#       undergraduation_score  work_ex  papers_published  \
# 8074                   2.84        3                 0
# 1459                   2.27        2                 0
# 502                    2.75        0                 0
# 1324                   2.24       60                 3
# 4883                   3.13        0                 3
# 8486                   3.05       17                 1
# 2020                   2.60       30                 1
# 7116                   3.56       40                 2
# 4213                   3.33       24                 0
# 4840                   3.44       10                 0
# 8910                   2.23       48                 0
# 2994                   3.63        3                 0
# 6786                   3.47       26                 0
# 9148                   3.68        0                 0
# 8852                   2.85        0                 0
# 8535                   3.34       12                 2
# 1774                   2.10       27                 0
# 1701                   2.92        4                 0
# 42                     3.33        2                 0
# 2764                   3.34        0                 0
# 7886                   2.28       20                 0
# 7538                   2.92       18                 0
# 2449                   3.12       20                 0
# 7955                   2.89        0                 0
# 1396                   2.54       29                 0
# 631                    3.14       17                 0
# 3210                   3.28        4                 0
# 150                    3.25        3                 0
# 404                    3.15       25                 0
# 6162                   2.15        0                 0
# ...                     ...      ...               ...
# 8617                   3.56        0                 0
# 6578                   2.90       20                 0
# 6307                   3.56        5                 0
# 575                    3.28       16                 0
# 718                    3.56       40                 0
# 6843                   3.56       31                 3
# 980                    2.55        0                 0
# 2899                   2.99       24                 0
# 605                    3.54       18                 3
# 6303                   3.68       20                 0
# 5226                   3.36        5                 2
# 2877                   3.23       30                 3
# 2108                   3.75       15                 3
# 4367                   3.10        0                 0
# 3773                   2.80        0                 0
# 1334                   3.28       16                 3
# 6249                   2.40        0                 0
# 5646                   2.47       33                 3
# 6038                   2.28       20                 0
# 3258                   3.29       30                 2
# 1787                   3.01        0                 0
# 549                    2.75        0                 0
# 2982                   2.91       20                 0
# 4065                   3.04        0                 0
# 3340                   2.52       36                 3
# 4541                   3.66       33                 1
# 2841                   2.84       20                 0
# 5297                   3.74       20                 0
# 6561                   3.29       32                 0
# 5191                   3.43       16                 0
#
#                                   university_name  status  ranking
# 8074                university_of_texas_arlington  accept       64
# 1459             illinois_institute_of_technology  accept       97
# 502                       northeastern_university  accept       15
# 1324             illinois_institute_of_technology  accept       97
# 4883             rutgers_university_new_brunswick  accept       25
# 8486                   university_of_texas_austin  reject       16
# 2020               indiana_university_bloomington  reject       48
# 7116              university_of_california_irvine  accept       23
# 4213                      northeastern_university  reject       15
# 4840             rutgers_university_new_brunswick  accept       25
# 8910                   university_of_texas_dallas  reject       52
# 2994      north_carolina_state_university_raleigh  reject       49
# 6786               university_of_colorado_boulder  accept       58
# 9148                     university_of_cincinnati  accept      130
# 8852                   university_of_texas_dallas  reject       52
# 8535                   university_of_texas_dallas  accept       52
# 1774               indiana_university_bloomington  accept       48
# 1701               indiana_university_bloomington  accept       48
# 42                        northeastern_university  accept       15
# 2764      north_carolina_state_university_raleigh  accept       49
# 7886    university_of_north_carolina_at_charlotte  reject       30
# 7538                        university_of_florida  reject       62
# 2449            michigan_technological_university  accept      117
# 7955            university_of_southern_california  reject       19
# 1396             illinois_institute_of_technology  accept       97
# 631                    carnegie_mellon_university  reject        1
# 3210                          new_york_university  accept       22
# 150                       northeastern_university  accept       15
# 404                       northeastern_university  accept       15
# 6162                          syracuse_university  reject      118
# ...                                           ...     ...      ...
# 8617                   university_of_texas_dallas  accept       52
# 6578         texas_a_m_university_college_station  reject       31
# 6307         texas_a_m_university_college_station  accept       31
# 575                    carnegie_mellon_university  reject        1
# 718                    carnegie_mellon_university  accept        1
# 6843               university_of_colorado_boulder  accept       58
# 980                       george_mason_university  accept       59
# 2899      north_carolina_state_university_raleigh  reject       49
# 605                    carnegie_mellon_university  reject        1
# 6303         texas_a_m_university_college_station  accept       31
# 5226  state_university_of_new_york_at_stony_brook  accept       35
# 2877      north_carolina_state_university_raleigh  reject       49
# 2108          university_of_maryland_college_park  accept       10
# 4367                      northeastern_university  reject       15
# 3773                      northeastern_university  reject       15
# 1334             illinois_institute_of_technology  accept       97
# 6249                          syracuse_university  reject      118
# 5646  state_university_of_new_york_at_stony_brook  reject       35
# 6038                          syracuse_university  reject      118
# 3258                          new_york_university  reject       22
# 1787               indiana_university_bloomington  accept       48
# 549                       northeastern_university  accept       15
# 2982      north_carolina_state_university_raleigh  reject       49
# 4065                      northeastern_university  reject       15
# 3340                          new_york_university  reject       22
# 4541            rochester_institute_of_technology  accept       66
# 2841      north_carolina_state_university_raleigh  reject       49
# 5297  state_university_of_new_york_at_stony_brook  accept       35
# 6561         texas_a_m_university_college_station  reject       31
# 5191  state_university_of_new_york_at_stony_brook  accept       35
#
# [2805 rows x 10 columns]

# %% [markdown]
# <b> Confusion matrix for test </b>

# %%
f,ax = plt.subplots(figsize=(2, 2))
sns.heatmap(test_cm, annot=True, linewidths=1, fmt= '.1f',ax=ax)
plt.show()

# %% [markdown]
# <b> Confusion Matrix for train </b>

# %%
train_cm = confusion_matrix(train['status'], saved_model.predict(train_frame).as_data_frame()['predict'],labels=['accept','reject'])
train_cm
# Out:
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# array([[2409,  637],
#        [  20, 3479]], dtype=int64)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
f,ax = plt.subplots(figsize=(2, 2))
sns.heatmap(train_cm, annot=True, linewidths=1, fmt= '.1f',ax=ax)
plt.show()

# %% [markdown]
# ## Test Accuracy Scores for train and test

# %%
test_accuracy = accuracy_score(test['status'], predictions.as_data_frame()['predict'])
print('test_accuracy:',test_accuracy)
train_accuracy = accuracy_score(train['status'], saved_model.predict(train_frame).as_data_frame()['predict'])
print('train_accuracy:',train_accuracy)
from sklearn.metrics import f1_score
test_f1_score = f1_score(test['status'], predictions.as_data_frame()['predict'],pos_label='accept')
print('test_f1_score:',test_f1_score)
train_f1_score = f1_score(train['status'], saved_model.predict(train_frame).as_data_frame()['predict'],pos_label='accept')
print('train_f1_score:',train_f1_score)
# Out:
# test_accuracy: 0.7244206773618538
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# train_accuracy: 0.8996180290297937
# test_f1_score: 0.6429561200923788
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# train_f1_score: 0.88

# %% [markdown]
# ## AUC ROC Curve

# %%
#test and train roc
test_fpr,test_tpr,test_thresholds = metrics.roc_curve(test['status'], predictions.as_data_frame()['accept'],pos_label='accept')
test_roc_auc = auc(test_fpr, test_tpr)
train_fpr,train_tpr,train_thresholds = metrics.roc_curve(train['status'], saved_model.predict(train_frame).as_data_frame()['accept'],pos_label='accept')
train_roc_auc = auc(train_fpr, train_tpr)
plt.plot(train_fpr, train_tpr, lw=2, alpha=0.5,
             label='Train ROC (auc= %0.2f)' % (train_roc_auc))
plt.plot(test_fpr, test_tpr, lw=2, alpha=0.5,
             label='Test ROC (auc= %0.2f)' % (test_roc_auc))
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
         label='Chance', alpha=.8)
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# stackedensemble prediction progress: |████████████████████████████████████| 100%

# %%
predictions.as_data_frame()['predict']
# Out:
# 0       accept
# 1       reject
# 2       reject
# 3       reject
# 4       accept
# 5       reject
# 6       reject
# 7       reject
# 8       reject
# 9       accept
# 10      reject
# 11      accept
# 12      accept
# 13      accept
# 14      reject
# 15      accept
# 16      accept
# 17      accept
# 18      reject
# 19      reject
# 20      reject
# 21      reject
# 22      accept
# 23      reject
# 24      accept
# 25      reject
# 26      reject
# 27      accept
# 28      reject
# 29      reject
#          ...
# 2775    accept
# 2776    reject
# 2777    reject
# 2778    reject
# 2779    reject
# 2780    accept
# 2781    accept
# 2782    reject
# 2783    reject
# 2784    accept
# 2785    reject
# 2786    reject
# 2787    reject
# 2788    reject
# 2789    reject
# 2790    accept
# 2791    reject
# 2792    reject
# 2793    reject
# 2794    reject
# 2795    accept
# 2796    reject
# 2797    reject
# 2798    reject
# 2799    reject
# 2800    accept
# 2801    reject
# 2802    accept
# 2803    reject
# 2804    reject
# Name: predict, Length: 2805, dtype: object

# %%
testing_df=test_frame.as_data_frame().join(predictions.as_data_frame())

# %%
wrong_prediction = testing_df.loc[testing_df['status']!=testing_df['predict'],:]

# %%
# wrong prediction results
wrong_prediction.university_name.value_counts()
# Out:
# northeastern_university                        161
# state_university_of_new_york_at_stony_brook     57
# syracuse_university                             52
# university_of_north_carolina_at_charlotte       46
# illinois_institute_of_technology                44
# new_york_university                             38
# north_carolina_state_university_raleigh         38
# university_of_california_irvine                 32
# university_of_texas_arlington                   29
# george_mason_university                         27
# rutgers_university_new_brunswick                27
# rochester_institute_of_technology               26
# texas_a_m_university_college_station            25
# indiana_university_bloomington                  23
# university_of_colorado_boulder                  22
# university_of_texas_dallas                      20
# clemson_university                              18
# kansas_state_university                         13
# university_of_cincinnati                        12
# carnegie_mellon_university                      11
# university_of_florida                            9
# michigan_technological_university                9
# university_of_maryland_college_park              9
# worcester_polytechnic_institute                  8
# university_of_connecticut                        6
# georgia_institiute_of_technology                 6
# university_of_texas_austin                       4
# university_of_southern_california                1
# Name: university_name, dtype: int64

# %% [markdown]
# <b> Summarization of the H2o.ai Results</b>

# %% [markdown]
# Best 4 Model have been summarized below:
# - StackedEnsemble_AllModels_AutoML_20190421_184847
# - StackedEnsemble_BestOfFamily_AutoML_20190421_184847
# - GBM_2_AutoML_20190421_184847
# - GBM_4_AutoML_20190421_184847

# %% [markdown]
# <b> Best Model Summary : StackedEnsemble_AllModels_AutoML_20190421_184847</b>
# <table>
#   <tr>
#     <th>Model</th>
#     <th>Train Accuracy</th>
#     <th>Test Accuracy</th>
#     <th>F1 Score - Train</th>
#     <th>F1 Score - Test</th>
#     <th>AUC-ROC Curve - Test</th>
#     <th>AUC-ROC Curve - Train</th>
#   </tr>
#   <tr>
#     <td>StackedEnsemble_AllModels_AutoML_20190421_184847</td>
#     <td>0.90</td>
#     <td>0.72</td>
#     <td>0.88</td>
#     <td>0.64</td>
#     <td>0.83</td>
#     <td>0.99</td>
#   </tr>
#
# </table>
