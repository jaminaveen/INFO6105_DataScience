# %% [markdown]
# ## This Notebook Covers
# - Scraping the profiles of the student data from Yocket for 29 Universities
# - The dataset has graduate student details for Admit and Reject for Computer Science Deaprtment

# %%
# Importing libraries
import requests
import pandas as pd
from selenium import webdriver
import time
from bs4 import BeautifulSoup

# %%
# Reading Data from the College Links File

# %%
df_computer_science = pd.read_csv(r'../../Data/29_college_links.csv')

# %%
# These are the admits and Rejects links for all universities for computer_science in 29 universities from Yocket
df_computer_science
# Out:
#                                          Reject_links  \
# 0   https://yocket.in/applications-admits-rejects/...
# 1   https://yocket.in/applications-admits-rejects/...
# 2   https://yocket.in/applications-admits-rejects/...
# 3   https://yocket.in/applications-admits-rejects/...
# 4   https://yocket.in/applications-admits-rejects/...
# 5   https://yocket.in/applications-admits-rejects/...
# 6   https://yocket.in/applications-admits-rejects/...
# 7   https://yocket.in/applications-admits-rejects/...
# 8   https://yocket.in/applications-admits-rejects/...
# 9   https://yocket.in/applications-admits-rejects/...
# 10  https://yocket.in/applications-admits-rejects/...
# 11  https://yocket.in/applications-admits-rejects/...
# 12  https://yocket.in/applications-admits-rejects/...
# 13  https://yocket.in/applications-admits-rejects/...
# 14  https://yocket.in/applications-admits-rejects/...
# 15  https://yocket.in/applications-admits-rejects/...
# 16  https://yocket.in/applications-admits-rejects/...
# 17  https://yocket.in/applications-admits-rejects/...
# 18  https://yocket.in/applications-admits-rejects/...
# 19  https://yocket.in/applications-admits-rejects/...
# 20  https://yocket.in/applications-admits-rejects/...
# 21  https://yocket.in/applications-admits-rejects/...
# 22  https://yocket.in/applications-admits-rejects/...
# 23  https://yocket.in/applications-admits-rejects/...
# 24  https://yocket.in/applications-admits-rejects/...
# 25  https://yocket.in/applications-admits-rejects/...
# 26  https://yocket.in/applications-admits-rejects/...
# 27  https://yocket.in/applications-admits-rejects/...
# 28  https://yocket.in/applications-admits-rejects/...
#
#                                          Accept_links
# 0   https://yocket.in/applications-admits-rejects/...
# 1   https://yocket.in/applications-admits-rejects/...
# 2   https://yocket.in/applications-admits-rejects/...
# 3   https://yocket.in/applications-admits-rejects/...
# 4   https://yocket.in/applications-admits-rejects/...
# 5   https://yocket.in/applications-admits-rejects/...
# 6   https://yocket.in/applications-admits-rejects/...
# 7   https://yocket.in/applications-admits-rejects/...
# 8   https://yocket.in/applications-admits-rejects/...
# 9   https://yocket.in/applications-admits-rejects/...
# 10  https://yocket.in/applications-admits-rejects/...
# 11  https://yocket.in/applications-admits-rejects/...
# 12  https://yocket.in/applications-admits-rejects/...
# 13  https://yocket.in/applications-admits-rejects/...
# 14  https://yocket.in/applications-admits-rejects/...
# 15  https://yocket.in/applications-admits-rejects/...
# 16  https://yocket.in/applications-admits-rejects/...
# 17  https://yocket.in/applications-admits-rejects/...
# 18  https://yocket.in/applications-admits-rejects/...
# 19  https://yocket.in/applications-admits-rejects/...
# 20  https://yocket.in/applications-admits-rejects/...
# 21  https://yocket.in/applications-admits-rejects/...
# 22  https://yocket.in/applications-admits-rejects/...
# 23  https://yocket.in/applications-admits-rejects/...
# 24  https://yocket.in/applications-admits-rejects/...
# 25  https://yocket.in/applications-admits-rejects/...
# 26  https://yocket.in/applications-admits-rejects/...
# 27  https://yocket.in/applications-admits-rejects/...
# 28  https://yocket.in/applications-admits-rejects/...

# %%
# Making admits and reject list for the universities
admits_links=[]
reject_links = []

reject_links = df_computer_science['Reject_links'].tolist()
admits_links = df_computer_science['Accept_links'].tolist()
required_colleges = ['northeastern university','illinois institute of technology','michigan technological university','rochester institute of technology','university of southern california','university of north carolina at charlotte','university of texas at arlington','university of texas at dallas','syracuse university','clemson university','new york university','indiana university bloomington','rutgers university-new brunswick','san jose state university','university of florida','Carnegie Mellon University','Georgia Institute of Technology','University of Colorado Boulder','North Carolina State University, Raleigh','University of Iowa','University of Connecticut','Worcester Polytechnic Institute','University of South Carolina','Kansas State University','University of Cincinnati','university of maryland, college park','University of California, Irvine','Texas A&M University, College Station','State University of New York at Stony Brook','George Mason University']

# %% [markdown]
# <b> Admit Records </b>
# - Here we will pass the admit links and scrape the top 7 pages. Here we will pass the accept links and scrape the top 7 pages for each university student profile for reject (Each page contains ~ 22 student record)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from fake_useragent import UserAgent

options = Options()
ua = UserAgent()
userAgent = ua.random

options.add_argument(f'user-agent={userAgent}')
driver = webdriver.Chrome(chrome_options=options, executable_path = '.\chrome_driver\chromedriver.exe')

driver.get('https://yocket.in/')
time.sleep(50)
# login to Yocket
for url in admits_links:
    for i in range(1,7):
        driver.get(url + '?page=' + str(i))
        html = driver.page_source
        soup = BeautifulSoup(html)
        name_containers = soup.find_all('div', class_ = 'col-sm-6')
        for i in name_containers:
            k =(i.div.text)
            t=[i for i in k.strip().split("\n") if len(i) is not 0]
            temp.append(t)
        time.sleep(15)
        r_accept= pd.DataFrame(temp)
r.rename(columns={0: 'student_name', 1: 'University_name', 2: 'year_applying', 3: 'Status',4: 'GRE',5: 'GRE_SCORE',6: 'Eng_test',7:'Test_score',8: 'Undergraduation',9: 'Undergraduation_score',10: 'is_work_ex', 11: 'work_ex'}, inplace=True)
r.to_csv('..\..\Data\Yocket_Acccept_University_student_data.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: use options instead of chrome_options
#   if sys.path[0] == '':

# %% [markdown]
# <b> Reject Records </b>
# - Here we will pass the reject links and scrape the top 7 pages for each university student profile for reject(Each page contains ~ 22 student record)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from fake_useragent import UserAgent

options = Options()
ua = UserAgent()
userAgent = ua.random

options.add_argument(f'user-agent={userAgent}')
driver = webdriver.Chrome(chrome_options=options, executable_path = '.\chrome_driver\chromedriver.exe')

driver.get('https://yocket.in/')
time.sleep(50)
# login to Yocket
for url in reject_links:
    for i in range(1,7):
        driver.get(url + '?page=' + str(i))
        html = driver.page_source
        soup = BeautifulSoup(html)
        name_containers = soup.find_all('div', class_ = 'col-sm-6')
        for i in name_containers:
            k =(i.div.text)
            t=[i for i in k.strip().split("\n") if len(i) is not 0]
            temp.append(t)
        time.sleep(15)
        r_reject= pd.DataFrame(temp)

r.rename(columns={0: 'student_name', 1: 'University_name', 2: 'year_applying', 3: 'Status',4: 'GRE',5: 'GRE_SCORE',6: 'Eng_test',7:'Test_score',8: 'Undergraduation',9: 'Undergraduation_score',10: 'is_work_ex', 11: 'work_ex'}, inplace=True)
r.to_csv('..\..\Data\Yocket_Reject_University_student_data.csv')
